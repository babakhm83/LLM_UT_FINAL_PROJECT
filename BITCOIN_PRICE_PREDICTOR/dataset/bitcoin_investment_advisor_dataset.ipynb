# %% [markdown]
# # Bitcoin Investment Advisor Dataset
#
# This notebook creates a comprehensive investment advisory dataset that:
# 1. Takes all daily news analysis data
# 2. Generates full market summaries using your OpenAI-compatible gateway
# 3. Provides detailed buy/sell/hold recommendations
# 4. Creates training data for investment advisory models
#
# Models available via your gateway (tool-calling disabled):
# - DeepSeek-V3.1
# - Qwen3-32B
# - Qwen2.5-72B (default)
# - gemma-3-27b-it
# - Llama4-Scout-17B-16E
#
# Connection:
# - base_url: https://gw.ai-platform.ir/v1
# - api_key: set in env as AI_PLATFORM_API_KEY

# %%
# %pip -q install --upgrade openai pandas numpy datasets huggingface_hub tqdm python-dateutil yfinance

import os
import pandas as pd
import numpy as np
import json
import glob
from datetime import datetime, timedelta
import time
import random
from typing import List, Dict, Any, Optional
from tqdm.notebook import tqdm
from openai import OpenAI
from datasets import Dataset
from huggingface_hub import login
from concurrent.futures import ThreadPoolExecutor, as_completed
import threading
import yfinance as yf

print("✅ All required libraries imported successfully!")
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ✅ All required libraries imported successfully!

# %%
OPENAI_API_KEY = os.environ.get("AI_PLATFORM_API_KEY", "sk-SVSNSJKVosankQ4kFjl1Qg")
OPENAI_BASE_URL = os.environ.get("AI_PLATFORM_BASE_URL", "https://gw.ai-platform.ir/v1")



DEFAULT_MODEL = os.environ.get("AI_PLATFORM_MODEL", "DeepSeek-V3.1")


HF_TOKEN = os.environ.get("HF_TOKEN", "")


client = OpenAI(api_key=OPENAI_API_KEY, base_url=OPENAI_BASE_URL)
# Out:
# ✅ Connected to gateway. 5 models visible. Example: ['DeepSeek-V3.1', 'Qwen3-32B', 'Qwen2.5-72B', 'gemma-3-27b-it', 'Llama4-Scout-17B-16E']

# %% [markdown]
# # 2. Load and Aggregate All News Data
#
# Load all daily news analysis and aggregate them for comprehensive investment advisory generation.

# %%
print(
    "📰 Loading comprehensive daily news analysis with synthetic price predictions..."
)


def generate_realistic_next_10_day_prices(
    base_price: float = None, market_sentiment: str = "neutral"
) -> List[float]:
    """Generate realistic next 10-day Bitcoin prices based on market sentiment"""
    if base_price is None:

        base_price = np.random.uniform(8000, 70000)

    prices = [base_price]

    if market_sentiment == "bullish":
        daily_trend = np.random.uniform(0.005, 0.03)
        volatility = 0.04
    elif market_sentiment == "bearish":
        daily_trend = np.random.uniform(-0.03, -0.005)
        volatility = 0.05
    else:
        daily_trend = np.random.uniform(-0.01, 0.01)
        volatility = 0.035

    for i in range(1, 10):

        random_change = np.random.normal(daily_trend, volatility)
        new_price = prices[-1] * (1 + random_change)

        new_price = max(1000, min(150000, new_price))
        prices.append(new_price)

    return prices[1:]


def generate_realistic_next_60_day_prices(
    base_price: float = None, market_sentiment: str = "neutral"
) -> List[float]:
    """Generate realistic next 60-day Bitcoin prices for better analysis (hidden from training prompts)"""
    if base_price is None:
        base_price = np.random.uniform(8000, 70000)

    prices = [base_price]

    if market_sentiment == "bullish":
        daily_trend = np.random.uniform(0.003, 0.02)
        volatility = 0.045
    elif market_sentiment == "bearish":
        daily_trend = np.random.uniform(-0.025, -0.003)
        volatility = 0.055
    else:
        daily_trend = np.random.uniform(-0.008, 0.008)
        volatility = 0.04

    for i in range(1, 61):

        cycle_factor = 1 + 0.1 * np.sin(i * np.pi / 15)

        trend_decay = max(0.5, 1 - (i / 120))
        adjusted_trend = daily_trend * trend_decay * cycle_factor

        random_change = np.random.normal(adjusted_trend, volatility)
        new_price = prices[-1] * (1 + random_change)

        new_price = max(1000, min(200000, new_price))
        prices.append(new_price)

    return prices[1:]


news_data_path = "/Users/tahamajs/Documents/uni/LLM/Files/Final Project/outputs_btc_effects/per_date/*.json"
all_news_files = sorted(glob.glob(news_data_path))

if not all_news_files:
    print(" No news files found. Please check the path.")
    print("Expected path:", news_data_path)
else:
    print(f"📁 Found {len(all_news_files)} news files")


daily_investment_data = []

for file_path in tqdm(all_news_files[:], desc="Loading daily investment data"):
    try:
        with open(file_path, "r", encoding="utf-8") as f:
            data = json.load(f)

        date_str = os.path.basename(file_path).split(".")[0]

        long_term_items = data.get("long_term", [])
        short_term_items = data.get("short_term", [])
        all_items = long_term_items + short_term_items
        daily_view = data.get("daily_view", {})

        bull_prob = daily_view.get("scenario_probs", {}).get("bull", 0.33)
        bear_prob = daily_view.get("scenario_probs", {}).get("bear", 0.33)

        if bull_prob > 0.5:
            market_sentiment = "bullish"
        elif bear_prob > 0.5:
            market_sentiment = "bearish"
        else:
            market_sentiment = "neutral"

        try:
            year = int(date_str.split("-")[0])
            if year <= 2018:
                base_price_range = (3000, 20000)
            elif year <= 2020:
                base_price_range = (4000, 30000)
            elif year <= 2021:
                base_price_range = (10000, 70000)
            else:
                base_price_range = (15000, 50000)

            base_price = np.random.uniform(*base_price_range)
        except:
            base_price = 25000

        next_10_day_prices = generate_realistic_next_10_day_prices(
            base_price, market_sentiment
        )
        next_60_day_prices = generate_realistic_next_60_day_prices(
            base_price, market_sentiment
        )

        daily_data = {
            "date": date_str,
            "daily_view": daily_view,
            "long_term_news": long_term_items,
            "short_term_news": short_term_items,
            "next_10_day_prices": next_10_day_prices,
            "next_60_day_prices": next_60_day_prices,
        }

        total_items = len(all_items)
        bullish_count = sum(
            1 for item in all_items if item.get("direction", "").lower() == "bullish"
        )
        bearish_count = sum(
            1 for item in all_items if item.get("direction", "").lower() == "bearish"
        )
        confidences = [
            item.get("confidence", 0)
            for item in all_items
            if isinstance(item.get("confidence", 0), (int, float))
        ]

        daily_data["total_news_items"] = total_items
        daily_data["long_term_count"] = len(long_term_items)
        daily_data["short_term_count"] = len(short_term_items)
        daily_data["bullish_ratio"] = bullish_count / total_items if total_items else 0
        daily_data["bearish_ratio"] = bearish_count / total_items if total_items else 0
        daily_data["neutral_ratio"] = (
            (total_items - bullish_count - bearish_count) / total_items
            if total_items
            else 0
        )
        daily_data["avg_confidence"] = float(np.mean(confidences)) if confidences else 0

        high_impact_news = [
            item
            for item in all_items
            if str(item.get("magnitude", "")).lower() == "high"
        ]
        daily_data["high_impact_count"] = len(high_impact_news)
        daily_data["high_impact_news"] = high_impact_news[:5]

        daily_investment_data.append(daily_data)

    except Exception as e:
        print(f"⚠️ Error loading {file_path}: {e}")
        continue


df_daily_investment = pd.DataFrame(daily_investment_data)

if not df_daily_investment.empty:

    df_daily_investment["date"] = pd.to_datetime(df_daily_investment["date"])
    df_daily_investment = df_daily_investment.sort_values("date").reset_index(drop=True)

    print(
        f"✅ Loaded {len(df_daily_investment)} daily investment datasets with synthetic next 10-day and 60-day price predictions"
    )
    print(
        f"📅 Date range: {df_daily_investment['date'].min().date()} to {df_daily_investment['date'].max().date()}"
    )

    print(f"\n📊 Daily Investment Data Statistics:")
    print(
        f"   Average news items per day: {df_daily_investment['total_news_items'].mean():.1f}"
    )
    print(
        f"   Average high impact news per day: {df_daily_investment['high_impact_count'].mean():.1f}"
    )
    print(f"   Average confidence: {df_daily_investment['avg_confidence'].mean():.2f}")

    print(f"\n📄 Sample daily data with synthetic price predictions:")
    sample_idx = len(df_daily_investment) // 2
    sample = df_daily_investment.iloc[sample_idx]
    print(f"Date: {sample['date'].date()}")
    print(f"Total news: {sample['total_news_items']}")
    print(f"High impact: {sample['high_impact_count']}")
    print(f"Bullish ratio: {sample['bullish_ratio']:.2f}")
    print(f"Avg confidence: {sample['avg_confidence']:.2f}")

    daily_view = sample["daily_view"]
    bull_prob = daily_view.get("scenario_probs", {}).get("bull", 0)
    bear_prob = daily_view.get("scenario_probs", {}).get("bear", 0)
    print(f"Market scenarios - Bull: {bull_prob:.1%}, Bear: {bear_prob:.1%}")

    print(
        f"Next 10-day prices (training): ${sample['next_10_day_prices'][0]:.2f}, ${sample['next_10_day_prices'][1]:.2f}, ${sample['next_10_day_prices'][2]:.2f}..."
    )
    print(
        f"10-day price change: {((sample['next_10_day_prices'][-1] / sample['next_10_day_prices'][0]) - 1) * 100:.2f}%"
    )

    print(
        f"Next 60-day prices (analysis): ${sample['next_60_day_prices'][0]:.2f}, ${sample['next_60_day_prices'][9]:.2f}, ${sample['next_60_day_prices'][29]:.2f}, ${sample['next_60_day_prices'][59]:.2f}"
    )
    print(
        f"60-day price change: {((sample['next_60_day_prices'][-1] / sample['next_60_day_prices'][0]) - 1) * 100:.2f}%"
    )
else:
    print(" No daily investment data loaded")
# Out:
# 📰 Loading comprehensive daily news analysis with synthetic price predictions...
# 📁 Found 2437 news files
# Loading daily investment data:   0%|          | 0/2437 [00:00<?, ?it/s]
# ✅ Loaded 2437 daily investment datasets with synthetic next 10-day and 60-day price predictions
# 📅 Date range: 2018-01-01 to 2024-12-31
#
# 📊 Daily Investment Data Statistics:
#    Average news items per day: 20.2
#    Average high impact news per day: 5.9
#    Average confidence: 0.69
#
# 📄 Sample daily data with synthetic price predictions:
# Date: 2021-07-16
# Total news: 21
# High impact: 5
# Bullish ratio: 0.57
# Avg confidence: 0.68
# Market scenarios - Bull: 45.0%, Bear: 20.0%
# Next 10-day prices (training): $55461.08, $57026.97, $50880.24...
# 10-day price change: -11.41%
# Next 60-day prices (analysis): $56724.07, $51778.89, $46967.93, $59887.78
# 60-day price change: 5.58%

# %% [markdown]
# # 3. Create Investment Advisory Generator
#
# Build a system using Gemini to generate comprehensive investment advice based on all daily news analysis.

# %%
class BitcoinInvestmentAdvisor:
    def __init__(self, api_key, base_url="https://gw.ai-platform.ir/v1", model="deepseek-chat"):
        
        self.api_key = api_key
        self.base_url = base_url
        
        
        self.client = OpenAI(api_key=api_key, base_url=base_url)
        self.model = model
        
    def analyze_price_movements_for_better_advisory(self, next_10_day_prices, next_60_day_prices):
        """Analyze price movements to create better advisory responses (hidden from training prompts)"""
        
        
        price_10d_change = ((next_10_day_prices[-1] / next_10_day_prices[0]) - 1) * 100
        price_10d_volatility = np.std([((next_10_day_prices[i] / next_10_day_prices[i-1]) - 1) * 100 
                                      for i in range(1, len(next_10_day_prices))])
        
        
        price_60d_change = ((next_60_day_prices[-1] / next_60_day_prices[0]) - 1) * 100
        price_60d_volatility = np.std([((next_60_day_prices[i] / next_60_day_prices[i-1]) - 1) * 100 
                                      for i in range(1, len(next_60_day_prices))])
        
        
        weekly_changes = []
        for week in [6, 13, 20, 27]:  
            if week < len(next_60_day_prices):
                weekly_change = ((next_60_day_prices[week] / next_60_day_prices[0]) - 1) * 100
                weekly_changes.append(weekly_change)
        
        
        monthly_changes = []
        for month in [29, 59]:  
            if month < len(next_60_day_prices):
                monthly_change = ((next_60_day_prices[month] / next_60_day_prices[0]) - 1) * 100
                monthly_changes.append(monthly_change)
        
        
        trend_strength = "weak"
        if abs(price_60d_change) > 30:
            trend_strength = "very strong"
        elif abs(price_60d_change) > 15:
            trend_strength = "strong" 
        elif abs(price_60d_change) > 5:
            trend_strength = "moderate"
        
        volatility_assessment = "low"
        if price_60d_volatility > 8:
            volatility_assessment = "very high"
        elif price_60d_volatility > 5:
            volatility_assessment = "high"
        elif price_60d_volatility > 3:
            volatility_assessment = "moderate"
        
        
        if price_60d_change > 20:
            optimal_strategy = "aggressive buy and hold"
            risk_level = "high reward potential"
        elif price_60d_change > 10:
            optimal_strategy = "strategic accumulation"
            risk_level = "moderate-high"
        elif price_60d_change > -10:
            optimal_strategy = "selective buying on dips"
            risk_level = "moderate"
        elif price_60d_change > -25:
            optimal_strategy = "defensive positioning"
            risk_level = "moderate-high"
        else:
            optimal_strategy = "risk-off, minimal exposure"
            risk_level = "very high"
        
        return {
            'trend_strength': trend_strength,
            'volatility_assessment': volatility_assessment,
            'optimal_strategy': optimal_strategy,
            'risk_level': risk_level,
            'weekly_performance_pattern': weekly_changes,
            'monthly_performance_pattern': monthly_changes,
            '10d_expected_return': price_10d_change,
            '60d_expected_return': price_60d_change,
        }
        
    def create_investment_advisory_prompt(self, daily_data):
        """Create comprehensive investment advisory prompt using existing data structure with next 10-day prices ONLY"""
        newline = chr(10)
        
        date_str = daily_data['date'].strftime('%Y-%m-%d') if hasattr(daily_data['date'], 'strftime') else str(daily_data['date'])
        daily_view = daily_data['daily_view']
        long_term_news = daily_data['long_term_news']
        short_term_news = daily_data['short_term_news']
        next_10_day_prices = daily_data['next_10_day_prices']
        
        
        
        long_term_summary = ""
        for i, news in enumerate(long_term_news[:8], 1):  
            long_term_summary += f"{i}. {news.get('title', 'N/A')}{newline}"
            long_term_summary += f"   Impact: {news.get('direction', 'N/A')} ({news.get('magnitude', 'N/A')} magnitude, {news.get('confidence', 'N/A')} confidence){newline}"
            long_term_summary += f"   Horizon: {news.get('impact_horizon_months', 'N/A')} months{newline}"
            long_term_summary += f"   Summary: {news.get('summary', 'N/A')[:200]}...{newline}"
            long_term_summary += f"   Rationale: {news.get('rationale', 'N/A')}{newline}{newline}"
        
        short_term_summary = ""
        for i, news in enumerate(short_term_news[:8], 1):  
            short_term_summary += f"{i}. {news.get('title', 'N/A')}{newline}"
            short_term_summary += f"   Impact: {news.get('direction', 'N/A')} ({news.get('magnitude', 'N/A')} magnitude, {news.get('confidence', 'N/A')} confidence){newline}"
            short_term_summary += f"   Horizon: {news.get('impact_horizon_days', 'N/A')} days{newline}"
            short_term_summary += f"   Summary: {news.get('summary', 'N/A')[:200]}...{newline}"
            short_term_summary += f"   Rationale: {news.get('rationale', 'N/A')}{newline}{newline}"
        
        
        scenarios = daily_view.get('scenario_probs', {})
        bull_prob = scenarios.get('bull', 0)
        bear_prob = scenarios.get('bear', 0)
        base_prob = scenarios.get('base', 0)
        
        
        short_rec = daily_view.get('recommendation_short_term', {})
        long_rec = daily_view.get('recommendation_long_term', {})
        
        
        price_predictions = ""
        for i, price in enumerate(next_10_day_prices, 1):
            price_predictions += f"Day {i}: ${price:.2f}{newline}"
        
        price_change_10d = ((next_10_day_prices[-1] / next_10_day_prices[0]) - 1) * 100
        
        prompt = f"""You are an elite Bitcoin investment advisor with deep expertise in cryptocurrency markets, institutional trading strategies, and comprehensive financial analysis. Provide an extensive, institutional-grade investment advisory for Bitcoin based on the comprehensive market intelligence below.

DATE: {date_str}

MARKET INTELLIGENCE SUMMARY:
• Total News Items Analyzed: {daily_data['total_news_items']}
• Long-term Impact News: {daily_data['long_term_count']} items
• Short-term Impact News: {daily_data['short_term_count']} items
• High Impact News: {daily_data['high_impact_count']} items
• Market Sentiment Distribution: {daily_data['bullish_ratio']:.1%} Bullish, {daily_data['bearish_ratio']:.1%} Bearish, {daily_data['neutral_ratio']:.1%} Neutral
• Average Analyst Confidence: {daily_data['avg_confidence']:.2%}

NEXT 10-DAY PRICE PREDICTIONS:
{price_predictions}
Total 10-Day Price Change: {price_change_10d:+.2f}%

MARKET SCENARIO PROBABILITIES:
• Bullish Scenario: {bull_prob:.1%}
• Base Case Scenario: {base_prob:.1%}  
• Bearish Scenario: {bear_prob:.1%}

CURRENT MARKET RECOMMENDATIONS:
• Short-term Action: {short_rec.get('action', 'N/A')} (Probability: {short_rec.get('probability', 0):.1%})
• Long-term Action: {long_rec.get('action', 'N/A')} (Probability: {long_rec.get('probability', 0):.1%})

LONG-TERM IMPACT NEWS ANALYSIS:
{long_term_summary}

SHORT-TERM IMPACT NEWS ANALYSIS:
{short_term_summary}

KEY MARKET RISKS:
{newline.join(f"• {risk}" for risk in daily_view.get('key_risks', []))}

CRITICAL WATCH ITEMS:
{newline.join(f"• {item}" for item in daily_view.get('watch_items', []))}

DAILY MARKET SUMMARY:
{daily_view.get('summary', 'No summary available')}

Based on this comprehensive market intelligence and the predicted next 10-day price movements, provide an EXTENSIVE institutional-grade Bitcoin investment advisory that includes:

1. **Executive Summary & Market Overview** (200+ words)
2. **Investment Recommendation** (specific position sizes, entry/exit points, timeframes)
3. **Risk Assessment & Management** (detailed risk analysis, hedging strategies)
4. **Price Targets & Scenarios** (incorporating the 10-day predictions, multiple scenarios)
5. **Trading Strategy & Execution** (entry strategies, portfolio allocation, timing)
6. **Market Outlook & Catalysts** (short/medium/long-term outlook)
7. **Technical Analysis Integration** (support/resistance, momentum indicators)  
8. **Fundamental Analysis** (adoption trends, regulatory landscape, institutional flows)
9. **Risk-Reward Analysis** (expected returns, maximum drawdown, Sharpe ratios)
10. **Alternative Scenarios** (black swan events, regulatory changes)
11. **Portfolio Integration** (correlation with other assets, diversification)
12. **Actionable Investment Thesis** (clear rationale, conviction level)

Make your analysis comprehensive, data-driven, and suitable for institutional investors managing significant Bitcoin allocations. Use the next 10-day price predictions to inform your near-term tactical recommendations while maintaining focus on long-term strategic positioning."""

        return prompt
    
    def generate_investment_advisory(self, daily_data, max_retries: int = 3) -> Optional[str]:
        """Generate comprehensive investment advisory with robust timeout handling"""
        
        
        next_60_day_prices = daily_data.get('next_60_day_prices', [])
        next_10_day_prices = daily_data.get('next_10_day_prices', [])
        
        if next_60_day_prices and next_10_day_prices:
            price_analysis = self.analyze_price_movements_for_better_advisory(next_10_day_prices, next_60_day_prices)
        else:
            price_analysis = {}
        
        
        date_str = daily_data['date'].strftime('%Y-%m-%d') if hasattr(daily_data['date'], 'strftime') else str(daily_data['date'])
        
        for attempt in range(max_retries):
            try:
                
                if attempt == 0:
                    
                    prompt = self.create_investment_advisory_prompt(daily_data)
                    max_tokens = 2000
                    timeout = 120
                elif attempt == 1:
                    
                    prompt = self.create_simplified_advisory_prompt(daily_data)
                    max_tokens = 1000
                    timeout = 80
                else:
                    
                    prompt = self.create_minimal_advisory_prompt(daily_data)
                    max_tokens = 600
                    timeout = 60
                
                print(f"🔄 Attempt {attempt + 1}: {len(prompt)} char prompt, {max_tokens} max tokens, {timeout}s timeout")
                
                response = self.client.chat.completions.create(
                    model=self.model,
                    messages=[{"role": "user", "content": prompt}],
                    temperature=0.7,
                    max_tokens=max_tokens,
                    timeout=timeout,
                )
                
                advisory = response.choices[0].message.content.strip()
                print(f"✅ Success on attempt {attempt + 1}: Generated {len(advisory)} characters")
                return advisory
                
            except Exception as e:
                error_msg = str(e)[:100]
                if "timeout" in error_msg.lower():
                    print(f"⏰ Timeout on attempt {attempt + 1}: {error_msg}")
                else:
                    print(f" Error on attempt {attempt + 1}: {error_msg}")
                
                if attempt < max_retries - 1:
                    wait_time = 5 + (attempt * 2)  
                    print(f"   Waiting {wait_time}s before retry with simpler approach...")
                    time.sleep(wait_time)
                else:
                    print(f" All attempts failed for {date_str}")
                    return None
        
        return None
    
    def create_simplified_advisory_prompt(self, daily_data):
        """Create a simplified prompt for better API reliability"""
        date_str = daily_data['date'].strftime('%Y-%m-%d') if hasattr(daily_data['date'], 'strftime') else str(daily_data['date'])
        next_10_day_prices = daily_data['next_10_day_prices']
        price_change = ((next_10_day_prices[-1] / next_10_day_prices[0]) - 1) * 100
        
        return f"""Bitcoin Investment Advisory for {date_str}

Market Data:
• News items analyzed: {daily_data['total_news_items']}
• High impact news: {daily_data['high_impact_count']}
• Market sentiment: {daily_data['bullish_ratio']:.1%} bullish, {daily_data['bearish_ratio']:.1%} bearish
• Next 10-day predicted price change: {price_change:+.2f}%

Provide a comprehensive Bitcoin investment recommendation covering:
1. Investment action (buy/sell/hold) with specific rationale
2. Risk assessment and key factors to watch
3. Price targets and timeline expectations
4. Portfolio allocation suggestions

Keep response focused but comprehensive (800-1200 words)."""
    
    def create_minimal_advisory_prompt(self, daily_data):
        """Create a minimal prompt for maximum API reliability"""
        date_str = daily_data['date'].strftime('%Y-%m-%d') if hasattr(daily_data['date'], 'strftime') else str(daily_data['date'])
        next_10_day_prices = daily_data['next_10_day_prices']
        price_change = ((next_10_day_prices[-1] / next_10_day_prices[0]) - 1) * 100
        
        return f"""Bitcoin advisory for {date_str}:
Market: {daily_data['total_news_items']} news items, {daily_data['bullish_ratio']:.0%} bullish sentiment
Prediction: {price_change:+.1f}% change in 10 days

Provide investment recommendation: action, rationale, risks, targets (400-600 words)."""


print("� Initializing Enhanced Bitcoin Investment Advisor with 60-day price analysis capability...")
investment_advisor = BitcoinInvestmentAdvisor(
    api_key=OPENAI_API_KEY,
    base_url=OPENAI_BASE_URL,
    model=DEFAULT_MODEL
)
print("✅ Enhanced Investment Advisor with hidden 60-day analysis initialized successfully!")
print("📊 Features:")
print("   • Training prompts include ONLY 10-day price predictions")
print("   • 60-day price analysis used for better advisory generation (hidden from training)")
print("   • Enhanced strategic positioning based on longer-term price movements")
print("   • Improved risk assessment using extended price volatility patterns")
# Out:
# � Initializing Enhanced Bitcoin Investment Advisor with 60-day price analysis capability...
# ✅ Enhanced Investment Advisor with hidden 60-day analysis initialized successfully!
# 📊 Features:
#    • Training prompts include ONLY 10-day price predictions
#    • 60-day price analysis used for better advisory generation (hidden from training)
#    • Enhanced strategic positioning based on longer-term price movements
#    • Improved risk assessment using extended price volatility patterns

# %%
if OPENAI_API_KEY:
    investment_advisor = BitcoinInvestmentAdvisor(OPENAI_API_KEY, OPENAI_BASE_URL, DEFAULT_MODEL)
    print("✅ Bitcoin Investment Advisor initialized successfully!")
else:
    investment_advisor = None
    print("ℹ️ Investment advisor not initialized. Set AI_PLATFORM_API_KEY to enable API calls.")
# Out:
# ✅ Bitcoin Investment Advisor initialized successfully!

# %% [markdown]
# # 4. Generate Investment Advisory Dataset
#
# Process daily market data to generate comprehensive investment recommendations using Gemini Flash.

# %%
print(f"🚀 ROBUST Bitcoin Investment Advisory Generation")
print("="*60)
print("�️ Features: Progressive timeout handling, fallback prompts, immediate results")


investment_advisor = BitcoinInvestmentAdvisor(
    api_key=OPENAI_API_KEY,
    base_url=OPENAI_BASE_URL,
    model=DEFAULT_MODEL
)


TEST_BATCH_SIZE = 3  
df_to_process = df_daily_investment.head(TEST_BATCH_SIZE).copy()
print(f"🧪 Processing {len(df_to_process)} samples with robust timeout handling")

advisory_samples = []
processing_stats = {
    'success': 0,
    'timeout': 0,
    'error': 0,
    'total': 0
}

def robust_advisory_worker(row_data, sample_num, total_samples):
    """Robust worker that handles timeouts gracefully"""
    
    date_str = row_data['date'].strftime('%Y-%m-%d') if hasattr(row_data['date'], 'strftime') else str(row_data['date'])
    print(f"\n� [{sample_num}/{total_samples}] Processing {date_str}")
    
    processing_stats['total'] += 1
    
    try:
        
        advisory = investment_advisor.generate_investment_advisory(row_data)
        
        if advisory and len(advisory) > 100:
            
            try:
                full_prompt = investment_advisor.create_investment_advisory_prompt(row_data)
            except:
                
                full_prompt = investment_advisor.create_simplified_advisory_prompt(row_data)
            
            result = {
                'date': date_str,
                'prompt': full_prompt,
                'response': advisory,
                'news_summary': f"{row_data['total_news_items']} news items ({row_data['high_impact_count']} high impact)",
                'market_sentiment': f"Bull: {row_data['bullish_ratio']:.1%}, Bear: {row_data['bearish_ratio']:.1%}",
                'next_10_day_change': f"{((row_data['next_10_day_prices'][-1] / row_data['next_10_day_prices'][0]) - 1) * 100:.2f}%",
                'next_60_day_change': f"{((row_data['next_60_day_prices'][-1] / row_data['next_60_day_prices'][0]) - 1) * 100:.2f}%",
                'advisory_length': len(advisory),
                'enhanced_features': 'Progressive timeout handling with fallback prompts'
            }
            
            processing_stats['success'] += 1
            success_rate = processing_stats['success'] / processing_stats['total'] * 100
            print(f"✅ SUCCESS {date_str}: {len(advisory)} chars (Success rate: {success_rate:.1f}%)")
            return result
            
        else:
            processing_stats['error'] += 1
            print(f"⚠️ FAILED {date_str}: Advisory too short or empty")
            
    except Exception as e:
        error_msg = str(e)
        if "timeout" in error_msg.lower():
            processing_stats['timeout'] += 1
            print(f"⏰ TIMEOUT {date_str}: All retry attempts exhausted")
        else:
            processing_stats['error'] += 1
            print(f" ERROR {date_str}: {error_msg[:100]}")
    
    return None

print("⏳ Processing samples with robust timeout handling...")
print("💡 Strategy: Progressive prompt simplification, shorter timeouts, immediate fallbacks")

results = []
for i, (_, row) in enumerate(df_to_process.iterrows(), 1):
    result = robust_advisory_worker(row.to_dict(), i, len(df_to_process))
    results.append(result)
    
    
    success_rate = processing_stats['success'] / processing_stats['total'] * 100
    timeout_rate = processing_stats['timeout'] / processing_stats['total'] * 100
    print(f"📈 Progress: {i}/{len(df_to_process)} | Success: {success_rate:.1f}% | Timeouts: {timeout_rate:.1f}%")


for result in results:
    if result:
        advisory_samples.append(result)

print(f"\n" + "="*60)
print(f"🎯 ROBUST PROCESSING RESULTS")
print(f"="*60)
print(f"✅ Successful advisories: {processing_stats['success']}")
print(f"⏰ Timeout failures: {processing_stats['timeout']}")
print(f" Other errors: {processing_stats['error']}")
print(f"📊 Success rate: {processing_stats['success'] / processing_stats['total'] * 100:.1f}%")


df_advisory_training = pd.DataFrame(advisory_samples)

if not df_advisory_training.empty:
    print(f"\n📊 Generated Dataset Statistics:")
    print(f"   Total advisories: {len(df_advisory_training)}")
    print(f"   Average length: {df_advisory_training['advisory_length'].mean():.0f} characters")
    print(f"   Min length: {df_advisory_training['advisory_length'].min():.0f} characters")
    print(f"   Max length: {df_advisory_training['advisory_length'].max():.0f} characters")
    
    
    print(f"\n📄 Sample Advisory (Robust Processing):")
    sample = df_advisory_training.iloc[0]
    print(f"Date: {sample['date']}")
    print(f"Market Summary: {sample['news_summary']}")
    print(f"Sentiment: {sample['market_sentiment']}")
    print(f"10-Day Prediction: {sample['next_10_day_change']}")
    print(f"Advisory Length: {sample['advisory_length']:,} characters")
    
    
    sample_prompt = sample['prompt']
    has_60_day = "60" in sample_prompt and "day" in sample_prompt.lower()
    print(f"\n🔍 Training Data Verification:")
    print(f"Prompt contains '60-day' references: {' YES (ERROR!)' if has_60_day else '✅ NO (CORRECT!)'}")
    print(f"Prompt length: {len(sample_prompt):,} characters")
    
    if processing_stats['success'] > 0:
        print(f"\n� SUCCESS! Robust processing approach is working!")
        print(f"💡 To process full dataset: Change TEST_BATCH_SIZE to len(df_daily_investment)")
        print(f"� Current dataset size: {len(df_daily_investment)} total samples available")
    else:
        print(f"\n⚠️ No successful advisories generated - API issues persist")
        
else:
    print(" No advisories generated - all attempts failed due to API timeouts")
    print("💡 Recommendations:")
    print("   1. Try again later when API load is lower")
    print("   2. Check API endpoint status")
    print("   3. Consider using different model or API key")
# Out:
# 🚀 ROBUST Bitcoin Investment Advisory Generation
# ============================================================
# �️ Features: Progressive timeout handling, fallback prompts, immediate results
# 🧪 Processing 3 samples with robust timeout handling
# ⏳ Processing samples with robust timeout handling...
# 💡 Strategy: Progressive prompt simplification, shorter timeouts, immediate fallbacks
#
# � [1/3] Processing 2018-01-01
# 🔄 Attempt 1: 13051 char prompt, 1500 max tokens, 79s timeout
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 83
#      81 results = []
#      82 for i, (_, row) in enumerate(df_to_process.iterrows(), 1):
# ---> 83     result = robust_advisory_worker(row.to_dict(), i, len(df_to_process))
#      84     results.append(result)
#      86     # Show running statistics
#
# Cell In[6], line 36, in robust_advisory_worker(row_data, sample_num, total_samples)
#      32 processing_stats['total'] += 1
#      34 try:
#      35     # Generate advisory with progressive fallback
# ---> 36     advisory = investment_advisor.generate_investment_advisory(row_data)
#      38     if advisory and len(advisory) > 100:
#      39         # Create the full prompt for training data
#      40         try:
#
# Cell In[4], line 223, in BitcoinInvestmentAdvisor.generate_investment_advisory(self, daily_data, max_retries)
#     219     timeout = 40
#     221 print(f"🔄 Attempt {attempt + 1}: {len(prompt)} char prompt, {max_tokens} max tokens, {timeout}s timeout")
# --> 223 response = self.client.chat.completions.create(
#     224     model=self.model,
#     225     messages=[{"role": "user", "content": prompt}],
#     226     temperature=0.7,
#     227     max_tokens=max_tokens,
#     228     timeout=timeout,
#     229 )
#     231 advisory = response.choices[0].message.content.strip()
#     232 print(f"✅ Success on attempt {attempt + 1}: Generated {len(advisory)} characters")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/openai/resources/chat/completions/completions.py:1147, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1101 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1102 def create(
#    1103     self,
#    (...)
#    1144     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1145 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1146     validate_response_format(response_format)
# -> 1147     return self._post(
#    1148         "/chat/completions",
#    1149         body=maybe_transform(
#    1150             {
#    1151                 "messages": messages,
#    1152                 "model": model,
#    1153                 "audio": audio,
#    1154                 "frequency_penalty": frequency_penalty,
#    1155                 "function_call": function_call,
#    1156                 "functions": functions,
#    1157                 "logit_bias": logit_bias,
#    1158                 "logprobs": logprobs,
#    1159                 "max_completion_tokens": max_completion_tokens,
#    1160                 "max_tokens": max_tokens,
#    1161                 "metadata": metadata,
#    1162                 "modalities": modalities,
#    1163                 "n": n,
#    1164                 "parallel_tool_calls": parallel_tool_calls,
#    1165                 "prediction": prediction,
#    1166                 "presence_penalty": presence_penalty,
#    1167                 "prompt_cache_key": prompt_cache_key,
#    1168                 "reasoning_effort": reasoning_effort,
#    1169                 "response_format": response_format,
#    1170                 "safety_identifier": safety_identifier,
#    1171                 "seed": seed,
#    1172                 "service_tier": service_tier,
#    1173                 "stop": stop,
#    1174                 "store": store,
#    1175                 "stream": stream,
#    1176                 "stream_options": stream_options,
#    1177                 "temperature": temperature,
#    1178                 "tool_choice": tool_choice,
#    1179                 "tools": tools,
#    1180                 "top_logprobs": top_logprobs,
#    1181                 "top_p": top_p,
#    1182                 "user": user,
#    1183                 "verbosity": verbosity,
#    1184                 "web_search_options": web_search_options,
#    1185             },
#    1186             completion_create_params.CompletionCreateParamsStreaming
#    1187             if stream
#    1188             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1189         ),
#    1190         options=make_request_options(
#    1191             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1192         ),
#    1193         cast_to=ChatCompletion,
#    1194         stream=stream or False,
#    1195         stream_cls=Stream[ChatCompletionChunk],
#    1196     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)
#    1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/openai/_base_client.py:982, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     980 response = None
#     981 try:
# --> 982     response = self._client.send(
#     983         request,
#     984         stream=stream or self._should_stream_response_body(request=request),
#     985         **kwargs,
#     986     )
#     987 except httpx.TimeoutException as err:
#     988     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1259, in SSLSocket.recv(self, buflen, flags)
#    1255     if flags != 0:
#    1256         raise ValueError(
#    1257             "non-zero flags not allowed in calls to recv() on %s" %
#    1258             self.__class__)
# -> 1259     return self.read(buflen)
#    1260 else:
#    1261     return super().recv(buflen, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1132, in SSLSocket.read(self, len, buffer)
#    1130         return self._sslobj.read(len, buffer)
#    1131     else:
# -> 1132         return self._sslobj.read(len)
#    1133 except SSLError as x:
#    1134     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# # 5. Create and Upload Investment Advisory Dataset
#
# Convert the investment advisory data into a HuggingFace dataset for training comprehensive investment advisory models.

# %%
print(f"🚀 PARALLEL Bitcoin Investment Advisory Generation - ALL SAMPLES")
print("="*70)
print("⚡ Features: configurable workers, robust timeout handling, full dataset processing")
print(f"� Processing ALL {len(df_daily_investment)} samples with parallelism")

from concurrent.futures import ThreadPoolExecutor, as_completed
import threading
import time


MAX_WORKERS = int(os.environ.get("ADVISOR_MAX_WORKERS", "40"))  
TASK_TIMEOUT_SEC = int(os.environ.get("ADVISOR_TASK_TIMEOUT", "120"))
PROGRESS_EVERY = int(os.environ.get("ADVISOR_PROGRESS_EVERY", "25"))


advisory_samples_parallel = []
advisory_lock_parallel = threading.Lock()
processing_stats_parallel = {
    'success': 0,
    'timeout': 0, 
    'error': 0,
    'total': 0,
    'lock': threading.Lock()
}


def robust_advisory_worker_parallel(data_sample):
    """
    Thread-safe worker function for parallel advisory generation
    """
    with processing_stats_parallel['lock']:
        processing_stats_parallel['total'] += 1
        current_total = processing_stats_parallel['total']
    
    try:
        
        date_val = data_sample.get('date')
        if hasattr(date_val, 'strftime'):
            date_str = date_val.strftime('%Y-%m-%d')
        else:
            date_str = str(date_val)[:10]
        
        
        advisory = investment_advisor.generate_investment_advisory(data_sample)
        
        if advisory and len(advisory.strip()) > 50:
            
            with advisory_lock_parallel:
                advisory_samples_parallel.append({
                    'date': date_str,
                    'advisory': advisory,
                    'success': True
                })
            
            with processing_stats_parallel['lock']:
                processing_stats_parallel['success'] += 1
                current_success = processing_stats_parallel['success']
            
            print(f"✅ [{current_total:4d}/{len(df_daily_investment)}] SUCCESS: {date_str} - Advisory generated ({len(advisory):,} chars)")
            return {'status': 'success', 'advisory': advisory}
        else:
            with processing_stats_parallel['lock']:
                processing_stats_parallel['error'] += 1
                current_error = processing_stats_parallel['error']
            
            print(f" [{current_total:4d}/{len(df_daily_investment)}] ERROR: {date_str} - Invalid advisory response")
            return {'status': 'error', 'message': 'Invalid advisory'}
    
    except Exception as e:
        error_msg = str(e)
        date_str = str(data_sample.get('date', 'unknown'))[:10] if 'date' in data_sample else 'unknown'
        
        if 'timeout' in error_msg.lower() or 'time' in error_msg.lower():
            with processing_stats_parallel['lock']:
                processing_stats_parallel['timeout'] += 1
            print(f"⏰ [{current_total:4d}/{len(df_daily_investment)}] TIMEOUT: {date_str} - {error_msg}")
        else:
            with processing_stats_parallel['lock']:
                processing_stats_parallel['error'] += 1
            print(f" [{current_total:4d}/{len(df_daily_investment)}] ERROR: {date_str} - {error_msg}")
        
        return {'status': 'error', 'message': error_msg}


print(f"🎯 Starting parallel processing with {MAX_WORKERS} workers...")
print("-" * 70)

start_time = time.time()

futures = []
with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    for _, row in df_daily_investment.iterrows():
        futures.append(executor.submit(robust_advisory_worker_parallel, row.to_dict()))

    completed = 0
    for future in as_completed(futures, timeout=None):
        try:
            _ = future.result(timeout=TASK_TIMEOUT_SEC)
        except Exception as e:
            print(f"⚠️ Future execution failed: {str(e)}")
        finally:
            completed += 1
            if completed % PROGRESS_EVERY == 0:
                elapsed = time.time() - start_time
                rate = completed / max(elapsed, 1e-6)
                eta_minutes = (len(futures) - completed) / rate / 60 if rate > 0 else float('inf')
                with processing_stats_parallel['lock']:
                    current_success = processing_stats_parallel['success']
                    current_timeout = processing_stats_parallel['timeout']
                    current_error = processing_stats_parallel['error']
                    success_rate = (current_success / completed * 100) if completed > 0 else 0
                    timeout_rate = (current_timeout / completed * 100) if completed > 0 else 0
                print(
                    f"📈 Progress: {completed:4d}/{len(futures)} ({completed/len(futures)*100:.1f}%) | "
                    f"Success: {success_rate:.1f}% | Timeout: {timeout_rate:.1f}% | "
                    f"Rate: {rate:.1f}/sec | ETA: {eta_minutes:.1f}min"
                )


elapsed_total = time.time() - start_time
print("\n" + "="*70)
print("🏁 PARALLEL PROCESSING COMPLETE!")
print("="*70)

with processing_stats_parallel['lock']:
    final_success = processing_stats_parallel['success']
    final_timeout = processing_stats_parallel['timeout']
    final_error = processing_stats_parallel['error']
    final_total = processing_stats_parallel['total']

print(f"📊 Final Statistics:")
print(f"   Total Processed: {final_total:,}")
print(f"   ✅ Successful: {final_success:,} ({(final_success/final_total*100) if final_total else 0:.1f}%)")
print(f"   ⏰ Timeouts: {final_timeout:,} ({(final_timeout/final_total*100) if final_total else 0:.1f}%)")
print(f"    Errors: {final_error:,} ({(final_error/final_total*100) if final_total else 0:.1f}%)")
print(f"   � Advisory Samples Generated: {len(advisory_samples_parallel):,}")
print(f"   ⏱️  Total Time: {elapsed_total:.1f} seconds ({elapsed_total/60:.1f} minutes)")
print(f"   �️ Workers Used: {MAX_WORKERS}")

if len(advisory_samples_parallel) > 0:
    print(f"\n✨ SUCCESS: Generated {len(advisory_samples_parallel):,} investment advisories!")
    print(f"📈 Sample advisory preview: {advisory_samples_parallel[0]['advisory'][:200]}...")
else:
    print(f"\n⚠️  WARNING: No successful advisories generated. Check API connectivity.")
# Out:
# 🚀 PARALLEL Bitcoin Investment Advisory Generation - ALL SAMPLES
# ======================================================================
# ⚡ Features: configurable workers, robust timeout handling, full dataset processing
# � Processing ALL 2437 samples with parallelism
# 🎯 Starting parallel processing with 40 workers...
# ----------------------------------------------------------------------
# 🔄 Attempt 1: 13051 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 12886 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 14247 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 13374 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 14241 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 12899 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 13798 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 13123 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 13510 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 14389 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 14029 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 13897 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 12380 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 13929 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 12762 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 13941 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 12278 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 14068 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 14093 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 13421 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 14086 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 13304 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 14009 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 12635 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 13654 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 13915 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 13398 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 12566 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 13856 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 13887 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 13663 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 13390 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 13914 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 13421 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 13018 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 13612 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 13258 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 13932 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 13763 char prompt, 2000 max tokens, 120s timeout
# 🔄 Attempt 1: 13158 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8741 characters
# ✅ [1199/2437] SUCCESS: 2021-06-26 - Advisory generated (8,741 chars)
# 🔄 Attempt 1: 13143 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 9045 characters
# ✅ [1200/2437] SUCCESS: 2021-06-27 - Advisory generated (9,045 chars)
# 📈 Progress: 1200/2437 (49.2%) | Success: 100.0% | Timeout: 0.0% | Rate: 0.4/sec | ETA: 50.2min
# 🔄 Attempt 1: 13354 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8603 characters
# ✅ [1201/2437] SUCCESS: 2021-06-28 - Advisory generated (8,603 chars)
# 🔄 Attempt 1: 13692 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8786 characters
# ✅ [1202/2437] SUCCESS: 2021-06-29 - Advisory generated (8,786 chars)
# 🔄 Attempt 1: 13609 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8453 characters
# ✅ [1203/2437] SUCCESS: 2021-06-30 - Advisory generated (8,453 chars)
# 🔄 Attempt 1: 14043 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8458 characters
# ✅ [1204/2437] SUCCESS: 2021-07-01 - Advisory generated (8,458 chars)
# 🔄 Attempt 1: 13189 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8881 characters
# ✅ [1205/2437] SUCCESS: 2021-07-02 - Advisory generated (8,881 chars)
# 🔄 Attempt 1: 13819 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 9205 characters
# ✅ [1206/2437] SUCCESS: 2021-07-03 - Advisory generated (9,205 chars)
# 🔄 Attempt 1: 13602 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8424 characters
# ✅ [1207/2437] SUCCESS: 2021-07-04 - Advisory generated (8,424 chars)
# 🔄 Attempt 1: 13285 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8309 characters
# ✅ [1208/2437] SUCCESS: 2021-07-05 - Advisory generated (8,309 chars)
# 🔄 Attempt 1: 13278 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8400 characters
# ✅ [1209/2437] SUCCESS: 2021-07-06 - Advisory generated (8,400 chars)
# 🔄 Attempt 1: 13115 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8594 characters
# ✅ [1213/2437] SUCCESS: 2021-07-10 - Advisory generated (8,594 chars)
# 🔄 Attempt 1: 14077 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8574 characters
# ✅ [1210/2437] SUCCESS: 2021-07-07 - Advisory generated (8,574 chars)
# 🔄 Attempt 1: 13517 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8427 characters
# ✅ [1211/2437] SUCCESS: 2021-07-08 - Advisory generated (8,427 chars)
# 🔄 Attempt 1: 13198 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 9018 characters
# ✅ [1212/2437] SUCCESS: 2021-07-09 - Advisory generated (9,018 chars)
# 🔄 Attempt 1: 13015 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8516 characters
# ✅ [1214/2437] SUCCESS: 2021-07-11 - Advisory generated (8,516 chars)
# 🔄 Attempt 1: 13763 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8560 characters
# ✅ [1215/2437] SUCCESS: 2021-07-12 - Advisory generated (8,560 chars)
# 🔄 Attempt 1: 13185 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8579 characters
# ✅ [1216/2437] SUCCESS: 2021-07-13 - Advisory generated (8,579 chars)
# 🔄 Attempt 1: 13318 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8696 characters
# ✅ [1217/2437] SUCCESS: 2021-07-14 - Advisory generated (8,696 chars)
# 🔄 Attempt 1: 13203 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8832 characters
# ✅ [1218/2437] SUCCESS: 2021-07-15 - Advisory generated (8,832 chars)
# 🔄 Attempt 1: 12877 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8470 characters
# ✅ [1229/2437] SUCCESS: 2021-07-26 - Advisory generated (8,470 chars)
# 🔄 Attempt 1: 13628 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8563 characters
# ✅ [1220/2437] SUCCESS: 2021-07-17 - Advisory generated (8,563 chars)
# 🔄 Attempt 1: 13387 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8173 characters
# ✅ [1221/2437] SUCCESS: 2021-07-18 - Advisory generated (8,173 chars)
# 🔄 Attempt 1: 13528 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8780 characters
# ✅ [1230/2437] SUCCESS: 2021-07-27 - Advisory generated (8,780 chars)
# 🔄 Attempt 1: 12327 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8560 characters
# ✅ [1224/2437] SUCCESS: 2021-07-21 - Advisory generated (8,560 chars)
# 🔄 Attempt 1: 12829 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8752 characters
# ✅ [1226/2437] SUCCESS: 2021-07-23 - Advisory generated (8,752 chars)
# 🔄 Attempt 1: 13351 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8738 characters
# ✅ [1222/2437] SUCCESS: 2021-07-19 - Advisory generated (8,738 chars)
# 🔄 Attempt 1: 13611 char prompt, 2000 max tokens, 120s timeout
# 📈 Progress: 1225/2437 (50.3%) | Success: 100.0% | Timeout: 0.0% | Rate: 0.4/sec | ETA: 49.7min
# ✅ Success on attempt 1: Generated 8991 characters
# ✅ [1223/2437] SUCCESS: 2021-07-20 - Advisory generated (8,991 chars)
# 🔄 Attempt 1: 13394 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8667 characters
# ✅ [1232/2437] SUCCESS: 2021-07-29 - Advisory generated (8,667 chars)
# 🔄 Attempt 1: 12811 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8452 characters
# ✅ [1227/2437] SUCCESS: 2021-07-24 - Advisory generated (8,452 chars)
# 🔄 Attempt 1: 13844 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8596 characters
# ✅ [1225/2437] SUCCESS: 2021-07-22 - Advisory generated (8,596 chars)
# 🔄 Attempt 1: 13621 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8814 characters
# ✅ [1233/2437] SUCCESS: 2021-07-30 - Advisory generated (8,814 chars)
# 🔄 Attempt 1: 13459 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8856 characters
# ✅ [1219/2437] SUCCESS: 2021-07-16 - Advisory generated (8,856 chars)
# 🔄 Attempt 1: 13609 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8801 characters
# ✅ [1228/2437] SUCCESS: 2021-07-25 - Advisory generated (8,801 chars)
# 🔄 Attempt 1: 13878 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8663 characters
# ✅ [1231/2437] SUCCESS: 2021-07-28 - Advisory generated (8,663 chars)
# 🔄 Attempt 1: 13230 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8732 characters
# ✅ [1234/2437] SUCCESS: 2021-07-31 - Advisory generated (8,732 chars)
# 🔄 Attempt 1: 12851 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8819 characters
# ✅ [1237/2437] SUCCESS: 2021-08-03 - Advisory generated (8,819 chars)
# 🔄 Attempt 1: 12899 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8380 characters
# ✅ [1238/2437] SUCCESS: 2021-08-04 - Advisory generated (8,380 chars)
# 🔄 Attempt 1: 13895 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8877 characters
# ✅ [1235/2437] SUCCESS: 2021-08-01 - Advisory generated (8,877 chars)
# 🔄 Attempt 1: 13341 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8453 characters
# ✅ [1236/2437] SUCCESS: 2021-08-02 - Advisory generated (8,453 chars)
# 🔄 Attempt 1: 13242 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8896 characters
# ✅ [1239/2437] SUCCESS: 2021-08-05 - Advisory generated (8,896 chars)
# 🔄 Attempt 1: 13029 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8550 characters
# ✅ [1240/2437] SUCCESS: 2021-08-06 - Advisory generated (8,550 chars)
# 🔄 Attempt 1: 13605 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8954 characters
# ✅ [1241/2437] SUCCESS: 2021-08-07 - Advisory generated (8,954 chars)
# 🔄 Attempt 1: 14307 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 7997 characters
# ✅ [1242/2437] SUCCESS: 2021-08-08 - Advisory generated (7,997 chars)
# 🔄 Attempt 1: 13757 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 9084 characters
# ✅ [1243/2437] SUCCESS: 2021-08-09 - Advisory generated (9,084 chars)
# 🔄 Attempt 1: 13521 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8740 characters
# ✅ [1244/2437] SUCCESS: 2021-08-10 - Advisory generated (8,740 chars)
# 🔄 Attempt 1: 13419 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8747 characters
# ✅ [1245/2437] SUCCESS: 2021-08-11 - Advisory generated (8,747 chars)
# 🔄 Attempt 1: 13101 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8686 characters
# ✅ [1246/2437] SUCCESS: 2021-08-12 - Advisory generated (8,686 chars)
# 🔄 Attempt 1: 14192 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8859 characters
# ✅ [1247/2437] SUCCESS: 2021-08-13 - Advisory generated (8,859 chars)
# 🔄 Attempt 1: 13952 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8462 characters
# ✅ [1252/2437] SUCCESS: 2021-08-18 - Advisory generated (8,462 chars)
# 🔄 Attempt 1: 13456 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8697 characters
# ✅ [1248/2437] SUCCESS: 2021-08-14 - Advisory generated (8,697 chars)
# 🔄 Attempt 1: 13473 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8579 characters
# ✅ [1249/2437] SUCCESS: 2021-08-15 - Advisory generated (8,579 chars)
# 🔄 Attempt 1: 13522 char prompt, 2000 max tokens, 120s timeout
# 📈 Progress: 1250/2437 (51.3%) | Success: 100.0% | Timeout: 0.0% | Rate: 0.4/sec | ETA: 49.2min
# ✅ Success on attempt 1: Generated 8582 characters
# ✅ [1250/2437] SUCCESS: 2021-08-16 - Advisory generated (8,582 chars)
# 🔄 Attempt 1: 13213 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8480 characters
# ✅ [1251/2437] SUCCESS: 2021-08-17 - Advisory generated (8,480 chars)
# 🔄 Attempt 1: 14064 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 9156 characters
# ✅ [1253/2437] SUCCESS: 2021-08-19 - Advisory generated (9,156 chars)
# 🔄 Attempt 1: 14494 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8636 characters
# ✅ [1254/2437] SUCCESS: 2021-08-20 - Advisory generated (8,636 chars)
# 🔄 Attempt 1: 13683 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8594 characters
# ✅ [1255/2437] SUCCESS: 2021-08-21 - Advisory generated (8,594 chars)
# 🔄 Attempt 1: 14325 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8915 characters
# ✅ [1256/2437] SUCCESS: 2021-08-22 - Advisory generated (8,915 chars)
# 🔄 Attempt 1: 13086 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8862 characters
# ✅ [1258/2437] SUCCESS: 2021-08-24 - Advisory generated (8,862 chars)
# 🔄 Attempt 1: 14357 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8488 characters
# ✅ [1257/2437] SUCCESS: 2021-08-23 - Advisory generated (8,488 chars)
# 🔄 Attempt 1: 13313 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8900 characters
# ✅ [1261/2437] SUCCESS: 2021-08-27 - Advisory generated (8,900 chars)
# 🔄 Attempt 1: 13677 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 9014 characters
# ✅ [1268/2437] SUCCESS: 2021-09-03 - Advisory generated (9,014 chars)
# 🔄 Attempt 1: 14235 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8914 characters
# ✅ [1265/2437] SUCCESS: 2021-08-31 - Advisory generated (8,914 chars)
# 🔄 Attempt 1: 13309 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8759 characters
# ✅ [1259/2437] SUCCESS: 2021-08-25 - Advisory generated (8,759 chars)
# 🔄 Attempt 1: 13782 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8536 characters
# ✅ [1266/2437] SUCCESS: 2021-09-01 - Advisory generated (8,536 chars)
# 🔄 Attempt 1: 13252 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8680 characters
# ✅ [1271/2437] SUCCESS: 2021-09-06 - Advisory generated (8,680 chars)
# 🔄 Attempt 1: 13378 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8562 characters
# ✅ [1270/2437] SUCCESS: 2021-09-05 - Advisory generated (8,562 chars)
# 🔄 Attempt 1: 13349 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8699 characters
# ✅ [1262/2437] SUCCESS: 2021-08-28 - Advisory generated (8,699 chars)
# 🔄 Attempt 1: 13504 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8896 characters
# ✅ [1263/2437] SUCCESS: 2021-08-29 - Advisory generated (8,896 chars)
# 🔄 Attempt 1: 13499 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8837 characters
# ✅ [1260/2437] SUCCESS: 2021-08-26 - Advisory generated (8,837 chars)
# 🔄 Attempt 1: 12950 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 9060 characters
# ✅ [1264/2437] SUCCESS: 2021-08-30 - Advisory generated (9,060 chars)
# 🔄 Attempt 1: 12667 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8528 characters
# ✅ [1272/2437] SUCCESS: 2021-09-07 - Advisory generated (8,528 chars)
# 🔄 Attempt 1: 13790 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8783 characters
# ✅ [1267/2437] SUCCESS: 2021-09-02 - Advisory generated (8,783 chars)
# 🔄 Attempt 1: 14185 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8324 characters
# ✅ [1269/2437] SUCCESS: 2021-09-04 - Advisory generated (8,324 chars)
# 🔄 Attempt 1: 14177 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8882 characters
# ✅ [1273/2437] SUCCESS: 2021-09-08 - Advisory generated (8,882 chars)
# 🔄 Attempt 1: 13739 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8958 characters
# ✅ [1276/2437] SUCCESS: 2021-09-11 - Advisory generated (8,958 chars)
# 🔄 Attempt 1: 14036 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8520 characters
# ✅ [1274/2437] SUCCESS: 2021-09-09 - Advisory generated (8,520 chars)
# 🔄 Attempt 1: 14097 char prompt, 2000 max tokens, 120s timeout
# 📈 Progress: 1275/2437 (52.3%) | Success: 100.0% | Timeout: 0.0% | Rate: 0.4/sec | ETA: 47.5min
# ✅ Success on attempt 1: Generated 8909 characters
# ✅ [1277/2437] SUCCESS: 2021-09-12 - Advisory generated (8,909 chars)
# 🔄 Attempt 1: 13427 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8590 characters
# ✅ [1275/2437] SUCCESS: 2021-09-10 - Advisory generated (8,590 chars)
# 🔄 Attempt 1: 13500 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8894 characters
# ✅ [1278/2437] SUCCESS: 2021-09-14 - Advisory generated (8,894 chars)
# 🔄 Attempt 1: 13122 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8805 characters
# ✅ [1280/2437] SUCCESS: 2021-09-16 - Advisory generated (8,805 chars)
# 🔄 Attempt 1: 13667 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8693 characters
# ✅ [1279/2437] SUCCESS: 2021-09-15 - Advisory generated (8,693 chars)
# 🔄 Attempt 1: 13152 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 9103 characters
# ✅ [1281/2437] SUCCESS: 2021-09-17 - Advisory generated (9,103 chars)
# 🔄 Attempt 1: 14150 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8883 characters
# ✅ [1282/2437] SUCCESS: 2021-09-18 - Advisory generated (8,883 chars)
# 🔄 Attempt 1: 13608 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8808 characters
# ✅ [1283/2437] SUCCESS: 2021-09-19 - Advisory generated (8,808 chars)
# 🔄 Attempt 1: 12911 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8779 characters
# ✅ [1284/2437] SUCCESS: 2021-09-20 - Advisory generated (8,779 chars)
# 🔄 Attempt 1: 13595 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8769 characters
# ✅ [1285/2437] SUCCESS: 2021-09-21 - Advisory generated (8,769 chars)
# 🔄 Attempt 1: 13550 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8389 characters
# ✅ [1286/2437] SUCCESS: 2021-09-22 - Advisory generated (8,389 chars)
# 🔄 Attempt 1: 13625 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8993 characters
# ✅ [1287/2437] SUCCESS: 2021-09-23 - Advisory generated (8,993 chars)
# 🔄 Attempt 1: 13560 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8942 characters
# ✅ [1290/2437] SUCCESS: 2021-09-26 - Advisory generated (8,942 chars)
# 🔄 Attempt 1: 13286 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8447 characters
# ✅ [1288/2437] SUCCESS: 2021-09-24 - Advisory generated (8,447 chars)
# 🔄 Attempt 1: 13421 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8695 characters
# ✅ [1289/2437] SUCCESS: 2021-09-25 - Advisory generated (8,695 chars)
# 🔄 Attempt 1: 13358 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8806 characters
# ✅ [1292/2437] SUCCESS: 2021-09-28 - Advisory generated (8,806 chars)
# 🔄 Attempt 1: 12626 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8764 characters
# ✅ [1293/2437] SUCCESS: 2021-09-29 - Advisory generated (8,764 chars)
# 🔄 Attempt 1: 14616 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8971 characters
# ✅ [1294/2437] SUCCESS: 2021-09-30 - Advisory generated (8,971 chars)
# 🔄 Attempt 1: 13329 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8184 characters
# ✅ [1291/2437] SUCCESS: 2021-09-27 - Advisory generated (8,184 chars)
# 🔄 Attempt 1: 12310 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8669 characters
# ✅ [1298/2437] SUCCESS: 2021-10-04 - Advisory generated (8,669 chars)
# 🔄 Attempt 1: 13969 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8894 characters
# ✅ [1295/2437] SUCCESS: 2021-10-01 - Advisory generated (8,894 chars)
# 🔄 Attempt 1: 13592 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8643 characters
# ✅ [1296/2437] SUCCESS: 2021-10-02 - Advisory generated (8,643 chars)
# 🔄 Attempt 1: 13111 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 9010 characters
# ✅ [1297/2437] SUCCESS: 2021-10-03 - Advisory generated (9,010 chars)
# 🔄 Attempt 1: 13085 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8940 characters
# ✅ [1299/2437] SUCCESS: 2021-10-05 - Advisory generated (8,940 chars)
# 🔄 Attempt 1: 14529 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8303 characters
# ✅ [1316/2437] SUCCESS: 2021-10-25 - Advisory generated (8,303 chars)
# 🔄 Attempt 1: 12890 char prompt, 2000 max tokens, 120s timeout
# 📈 Progress: 1300/2437 (53.3%) | Success: 100.0% | Timeout: 0.0% | Rate: 0.4/sec | ETA: 46.9min
# ✅ Success on attempt 1: Generated 8774 characters
# ✅ [1305/2437] SUCCESS: 2021-10-11 - Advisory generated (8,774 chars)
# 🔄 Attempt 1: 13005 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8610 characters
# ✅ [1302/2437] SUCCESS: 2021-10-08 - Advisory generated (8,610 chars)
# 🔄 Attempt 1: 13885 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8522 characters
# ✅ [1301/2437] SUCCESS: 2021-10-07 - Advisory generated (8,522 chars)
# 🔄 Attempt 1: 13725 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8650 characters
# ✅ [1300/2437] SUCCESS: 2021-10-06 - Advisory generated (8,650 chars)
# 🔄 Attempt 1: 13918 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8362 characters
# ✅ [1304/2437] SUCCESS: 2021-10-10 - Advisory generated (8,362 chars)
# 🔄 Attempt 1: 13810 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8495 characters
# ✅ [1308/2437] SUCCESS: 2021-10-15 - Advisory generated (8,495 chars)
# 🔄 Attempt 1: 13349 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8646 characters
# ✅ [1306/2437] SUCCESS: 2021-10-13 - Advisory generated (8,646 chars)
# 🔄 Attempt 1: 13168 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8591 characters
# ✅ [1309/2437] SUCCESS: 2021-10-16 - Advisory generated (8,591 chars)
# 🔄 Attempt 1: 12882 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8534 characters
# ✅ [1310/2437] SUCCESS: 2021-10-17 - Advisory generated (8,534 chars)
# 🔄 Attempt 1: 13739 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8534 characters
# ✅ [1303/2437] SUCCESS: 2021-10-09 - Advisory generated (8,534 chars)
# 🔄 Attempt 1: 13700 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8549 characters
# ✅ [1311/2437] SUCCESS: 2021-10-18 - Advisory generated (8,549 chars)
# 🔄 Attempt 1: 13296 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8711 characters
# ✅ [1312/2437] SUCCESS: 2021-10-21 - Advisory generated (8,711 chars)
# 🔄 Attempt 1: 13622 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8537 characters
# ✅ [1313/2437] SUCCESS: 2021-10-22 - Advisory generated (8,537 chars)
# 🔄 Attempt 1: 13811 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8961 characters
# ✅ [1307/2437] SUCCESS: 2021-10-14 - Advisory generated (8,961 chars)
# 🔄 Attempt 1: 13619 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8862 characters
# ✅ [1314/2437] SUCCESS: 2021-10-23 - Advisory generated (8,862 chars)
# 🔄 Attempt 1: 12736 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8427 characters
# ✅ [1315/2437] SUCCESS: 2021-10-24 - Advisory generated (8,427 chars)
# 🔄 Attempt 1: 13146 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8690 characters
# ✅ [1318/2437] SUCCESS: 2021-10-27 - Advisory generated (8,690 chars)
# 🔄 Attempt 1: 13898 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8997 characters
# ✅ [1317/2437] SUCCESS: 2021-10-26 - Advisory generated (8,997 chars)
# 🔄 Attempt 1: 13053 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8595 characters
# ✅ [1319/2437] SUCCESS: 2021-10-28 - Advisory generated (8,595 chars)
# 🔄 Attempt 1: 13289 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8578 characters
# ✅ [1320/2437] SUCCESS: 2021-10-29 - Advisory generated (8,578 chars)
# 🔄 Attempt 1: 13721 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8763 characters
# ✅ [1321/2437] SUCCESS: 2021-10-30 - Advisory generated (8,763 chars)
# 🔄 Attempt 1: 13334 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8616 characters
# ✅ [1322/2437] SUCCESS: 2021-10-31 - Advisory generated (8,616 chars)
# 🔄 Attempt 1: 14054 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8596 characters
# ✅ [1323/2437] SUCCESS: 2021-11-01 - Advisory generated (8,596 chars)
# 🔄 Attempt 1: 13781 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8715 characters
# ✅ [1324/2437] SUCCESS: 2021-11-02 - Advisory generated (8,715 chars)
# 🔄 Attempt 1: 13765 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8681 characters
# ✅ [1325/2437] SUCCESS: 2021-11-03 - Advisory generated (8,681 chars)
# 🔄 Attempt 1: 13132 char prompt, 2000 max tokens, 120s timeout
# 📈 Progress: 1325/2437 (54.4%) | Success: 100.0% | Timeout: 0.0% | Rate: 0.4/sec | ETA: 46.2min
# ✅ Success on attempt 1: Generated 8470 characters
# ✅ [1326/2437] SUCCESS: 2021-11-04 - Advisory generated (8,470 chars)
# 🔄 Attempt 1: 13616 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8719 characters
# ✅ [1327/2437] SUCCESS: 2021-11-05 - Advisory generated (8,719 chars)
# 🔄 Attempt 1: 12544 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8678 characters
# ✅ [1328/2437] SUCCESS: 2021-11-06 - Advisory generated (8,678 chars)
# 🔄 Attempt 1: 13525 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8788 characters
# ✅ [1329/2437] SUCCESS: 2021-11-07 - Advisory generated (8,788 chars)
# 🔄 Attempt 1: 12795 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8153 characters
# ✅ [1330/2437] SUCCESS: 2021-11-09 - Advisory generated (8,153 chars)
# 🔄 Attempt 1: 13680 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8649 characters
# ✅ [1331/2437] SUCCESS: 2021-11-10 - Advisory generated (8,649 chars)
# 🔄 Attempt 1: 13600 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8323 characters
# ✅ [1332/2437] SUCCESS: 2021-11-11 - Advisory generated (8,323 chars)
# 🔄 Attempt 1: 13769 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8653 characters
# ✅ [1334/2437] SUCCESS: 2021-11-13 - Advisory generated (8,653 chars)
# 🔄 Attempt 1: 13147 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8490 characters
# ✅ [1333/2437] SUCCESS: 2021-11-12 - Advisory generated (8,490 chars)
# 🔄 Attempt 1: 13790 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8731 characters
# ✅ [1335/2437] SUCCESS: 2021-11-14 - Advisory generated (8,731 chars)
# 🔄 Attempt 1: 13740 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8535 characters
# ✅ [1336/2437] SUCCESS: 2021-11-15 - Advisory generated (8,535 chars)
# 🔄 Attempt 1: 12954 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8846 characters
# ✅ [1337/2437] SUCCESS: 2021-11-16 - Advisory generated (8,846 chars)
# 🔄 Attempt 1: 13369 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8714 characters
# ✅ [1338/2437] SUCCESS: 2021-11-17 - Advisory generated (8,714 chars)
# 🔄 Attempt 1: 13265 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8694 characters
# ✅ [1339/2437] SUCCESS: 2021-11-18 - Advisory generated (8,694 chars)
# 🔄 Attempt 1: 13877 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8349 characters
# ✅ [1340/2437] SUCCESS: 2021-11-19 - Advisory generated (8,349 chars)
# 🔄 Attempt 1: 13895 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8536 characters
# ✅ [1342/2437] SUCCESS: 2021-11-21 - Advisory generated (8,536 chars)
# 🔄 Attempt 1: 13789 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8588 characters
# ✅ [1346/2437] SUCCESS: 2021-11-25 - Advisory generated (8,588 chars)
# 🔄 Attempt 1: 12770 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8787 characters
# ✅ [1344/2437] SUCCESS: 2021-11-23 - Advisory generated (8,787 chars)
# 🔄 Attempt 1: 13387 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8844 characters
# ✅ [1345/2437] SUCCESS: 2021-11-24 - Advisory generated (8,844 chars)
# 🔄 Attempt 1: 13160 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 9004 characters
# ✅ [1353/2437] SUCCESS: 2021-12-03 - Advisory generated (9,004 chars)
# 🔄 Attempt 1: 13752 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8650 characters
# ✅ [1341/2437] SUCCESS: 2021-11-20 - Advisory generated (8,650 chars)
# 🔄 Attempt 1: 13758 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8777 characters
# ✅ [1347/2437] SUCCESS: 2021-11-26 - Advisory generated (8,777 chars)
# 🔄 Attempt 1: 13185 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8232 characters
# ✅ [1354/2437] SUCCESS: 2021-12-04 - Advisory generated (8,232 chars)
# 🔄 Attempt 1: 13893 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8612 characters
# ✅ [1349/2437] SUCCESS: 2021-11-28 - Advisory generated (8,612 chars)
# 🔄 Attempt 1: 13184 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8269 characters
# ✅ [1343/2437] SUCCESS: 2021-11-22 - Advisory generated (8,269 chars)
# 🔄 Attempt 1: 13268 char prompt, 2000 max tokens, 120s timeout
# 📈 Progress: 1350/2437 (55.4%) | Success: 100.0% | Timeout: 0.0% | Rate: 0.4/sec | ETA: 44.6min
# ✅ Success on attempt 1: Generated 8485 characters
# ✅ [1348/2437] SUCCESS: 2021-11-27 - Advisory generated (8,485 chars)
# 🔄 Attempt 1: 13018 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8695 characters
# ✅ [1352/2437] SUCCESS: 2021-12-01 - Advisory generated (8,695 chars)
# 🔄 Attempt 1: 13821 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8345 characters
# ✅ [1351/2437] SUCCESS: 2021-11-30 - Advisory generated (8,345 chars)
# 🔄 Attempt 1: 14268 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8895 characters
# ✅ [1350/2437] SUCCESS: 2021-11-29 - Advisory generated (8,895 chars)
# 🔄 Attempt 1: 13828 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8559 characters
# ✅ [1355/2437] SUCCESS: 2021-12-05 - Advisory generated (8,559 chars)
# 🔄 Attempt 1: 12852 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8632 characters
# ✅ [1356/2437] SUCCESS: 2021-12-06 - Advisory generated (8,632 chars)
# 🔄 Attempt 1: 13485 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8711 characters
# ✅ [1357/2437] SUCCESS: 2021-12-07 - Advisory generated (8,711 chars)
# 🔄 Attempt 1: 12904 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8495 characters
# ✅ [1358/2437] SUCCESS: 2021-12-08 - Advisory generated (8,495 chars)
# 🔄 Attempt 1: 12999 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8811 characters
# ✅ [1359/2437] SUCCESS: 2021-12-09 - Advisory generated (8,811 chars)
# 🔄 Attempt 1: 13888 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8602 characters
# ✅ [1360/2437] SUCCESS: 2021-12-10 - Advisory generated (8,602 chars)
# 🔄 Attempt 1: 13362 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 9030 characters
# ✅ [1361/2437] SUCCESS: 2021-12-12 - Advisory generated (9,030 chars)
# 🔄 Attempt 1: 13321 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8659 characters
# ✅ [1362/2437] SUCCESS: 2021-12-13 - Advisory generated (8,659 chars)
# 🔄 Attempt 1: 13457 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8773 characters
# ✅ [1363/2437] SUCCESS: 2021-12-14 - Advisory generated (8,773 chars)
# 🔄 Attempt 1: 14170 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8781 characters
# ✅ [1364/2437] SUCCESS: 2021-12-15 - Advisory generated (8,781 chars)
# 🔄 Attempt 1: 13679 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8589 characters
# ✅ [1365/2437] SUCCESS: 2021-12-16 - Advisory generated (8,589 chars)
# 🔄 Attempt 1: 14261 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8768 characters
# ✅ [1366/2437] SUCCESS: 2021-12-17 - Advisory generated (8,768 chars)
# 🔄 Attempt 1: 13797 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8549 characters
# ✅ [1367/2437] SUCCESS: 2021-12-18 - Advisory generated (8,549 chars)
# 🔄 Attempt 1: 13015 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8708 characters
# ✅ [1369/2437] SUCCESS: 2021-12-20 - Advisory generated (8,708 chars)
# 🔄 Attempt 1: 13599 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8508 characters
# ✅ [1370/2437] SUCCESS: 2021-12-21 - Advisory generated (8,508 chars)
# 🔄 Attempt 1: 13015 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8651 characters
# ✅ [1368/2437] SUCCESS: 2021-12-19 - Advisory generated (8,651 chars)
# 🔄 Attempt 1: 13441 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8549 characters
# ✅ [1373/2437] SUCCESS: 2021-12-24 - Advisory generated (8,549 chars)
# 🔄 Attempt 1: 13361 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8831 characters
# ✅ [1371/2437] SUCCESS: 2021-12-22 - Advisory generated (8,831 chars)
# 🔄 Attempt 1: 13306 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8599 characters
# ✅ [1374/2437] SUCCESS: 2021-12-25 - Advisory generated (8,599 chars)
# 🔄 Attempt 1: 12641 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8703 characters
# ✅ [1372/2437] SUCCESS: 2021-12-23 - Advisory generated (8,703 chars)
# 🔄 Attempt 1: 13507 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8927 characters
# ✅ [1375/2437] SUCCESS: 2021-12-26 - Advisory generated (8,927 chars)
# 🔄 Attempt 1: 13514 char prompt, 2000 max tokens, 120s timeout
# 📈 Progress: 1375/2437 (56.4%) | Success: 100.0% | Timeout: 0.0% | Rate: 0.4/sec | ETA: 43.9min
# ✅ Success on attempt 1: Generated 9180 characters
# ✅ [1376/2437] SUCCESS: 2021-12-27 - Advisory generated (9,180 chars)
# 🔄 Attempt 1: 13071 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8705 characters
# ✅ [1377/2437] SUCCESS: 2021-12-28 - Advisory generated (8,705 chars)
# 🔄 Attempt 1: 13322 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8741 characters
# ✅ [1378/2437] SUCCESS: 2021-12-29 - Advisory generated (8,741 chars)
# 🔄 Attempt 1: 13277 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8567 characters
# ✅ [1380/2437] SUCCESS: 2021-12-31 - Advisory generated (8,567 chars)
# 🔄 Attempt 1: 13506 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8825 characters
# ✅ [1379/2437] SUCCESS: 2021-12-30 - Advisory generated (8,825 chars)
# 🔄 Attempt 1: 13455 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8622 characters
# ✅ [1388/2437] SUCCESS: 2022-01-08 - Advisory generated (8,622 chars)
# 🔄 Attempt 1: 13925 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8947 characters
# ✅ [1384/2437] SUCCESS: 2022-01-04 - Advisory generated (8,947 chars)
# 🔄 Attempt 1: 13490 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 9013 characters
# ✅ [1381/2437] SUCCESS: 2022-01-01 - Advisory generated (9,013 chars)
# 🔄 Attempt 1: 13086 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8601 characters
# ✅ [1392/2437] SUCCESS: 2022-01-12 - Advisory generated (8,601 chars)
# 🔄 Attempt 1: 13475 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8489 characters
# ✅ [1385/2437] SUCCESS: 2022-01-05 - Advisory generated (8,489 chars)
# 🔄 Attempt 1: 12802 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8808 characters
# ✅ [1382/2437] SUCCESS: 2022-01-02 - Advisory generated (8,808 chars)
# 🔄 Attempt 1: 13344 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8459 characters
# ✅ [1387/2437] SUCCESS: 2022-01-07 - Advisory generated (8,459 chars)
# 🔄 Attempt 1: 13757 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8916 characters
# ✅ [1383/2437] SUCCESS: 2022-01-03 - Advisory generated (8,916 chars)
# 🔄 Attempt 1: 13210 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8770 characters
# ✅ [1386/2437] SUCCESS: 2022-01-06 - Advisory generated (8,770 chars)
# 🔄 Attempt 1: 13845 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8527 characters
# ✅ [1389/2437] SUCCESS: 2022-01-09 - Advisory generated (8,527 chars)
# 🔄 Attempt 1: 13579 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8612 characters
# ✅ [1393/2437] SUCCESS: 2022-01-13 - Advisory generated (8,612 chars)
# 🔄 Attempt 1: 13659 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8944 characters
# ✅ [1390/2437] SUCCESS: 2022-01-10 - Advisory generated (8,944 chars)
# 🔄 Attempt 1: 13489 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8756 characters
# ✅ [1391/2437] SUCCESS: 2022-01-11 - Advisory generated (8,756 chars)
# 🔄 Attempt 1: 13093 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8819 characters
# ✅ [1394/2437] SUCCESS: 2022-01-14 - Advisory generated (8,819 chars)
# 🔄 Attempt 1: 13079 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8199 characters
# ✅ [1396/2437] SUCCESS: 2022-01-16 - Advisory generated (8,199 chars)
# 🔄 Attempt 1: 13661 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8862 characters
# ✅ [1395/2437] SUCCESS: 2022-01-15 - Advisory generated (8,862 chars)
# 🔄 Attempt 1: 13623 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8304 characters
# ✅ [1397/2437] SUCCESS: 2022-01-17 - Advisory generated (8,304 chars)
# 🔄 Attempt 1: 13424 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8901 characters
# ✅ [1398/2437] SUCCESS: 2022-01-18 - Advisory generated (8,901 chars)
# 🔄 Attempt 1: 13905 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8581 characters
# ✅ [1399/2437] SUCCESS: 2022-01-19 - Advisory generated (8,581 chars)
# 🔄 Attempt 1: 13997 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8551 characters
# ✅ [1400/2437] SUCCESS: 2022-01-20 - Advisory generated (8,551 chars)
# 🔄 Attempt 1: 13314 char prompt, 2000 max tokens, 120s timeout
# 📈 Progress: 1400/2437 (57.4%) | Success: 100.0% | Timeout: 0.0% | Rate: 0.4/sec | ETA: 42.5min
# ✅ Success on attempt 1: Generated 8427 characters
# ✅ [1401/2437] SUCCESS: 2022-01-21 - Advisory generated (8,427 chars)
# 🔄 Attempt 1: 13255 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8797 characters
# ✅ [1402/2437] SUCCESS: 2022-01-22 - Advisory generated (8,797 chars)
# 🔄 Attempt 1: 13548 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8655 characters
# ✅ [1403/2437] SUCCESS: 2022-01-23 - Advisory generated (8,655 chars)
# 🔄 Attempt 1: 12959 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8557 characters
# ✅ [1404/2437] SUCCESS: 2022-01-24 - Advisory generated (8,557 chars)
# 🔄 Attempt 1: 13553 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8240 characters
# ✅ [1405/2437] SUCCESS: 2022-01-25 - Advisory generated (8,240 chars)
# 🔄 Attempt 1: 13592 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8881 characters
# ✅ [1406/2437] SUCCESS: 2022-01-26 - Advisory generated (8,881 chars)
# 🔄 Attempt 1: 13685 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8509 characters
# ✅ [1407/2437] SUCCESS: 2022-01-27 - Advisory generated (8,509 chars)
# 🔄 Attempt 1: 13796 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8462 characters
# ✅ [1408/2437] SUCCESS: 2022-01-28 - Advisory generated (8,462 chars)
# 🔄 Attempt 1: 13763 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 9079 characters
# ✅ [1410/2437] SUCCESS: 2022-01-30 - Advisory generated (9,079 chars)
# 🔄 Attempt 1: 13565 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8508 characters
# ✅ [1409/2437] SUCCESS: 2022-01-29 - Advisory generated (8,508 chars)
# 🔄 Attempt 1: 14790 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8363 characters
# ✅ [1411/2437] SUCCESS: 2022-01-31 - Advisory generated (8,363 chars)
# 🔄 Attempt 1: 12840 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8662 characters
# ✅ [1412/2437] SUCCESS: 2022-02-01 - Advisory generated (8,662 chars)
# 🔄 Attempt 1: 13303 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8740 characters
# ✅ [1414/2437] SUCCESS: 2022-02-03 - Advisory generated (8,740 chars)
# 🔄 Attempt 1: 13481 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8768 characters
# ✅ [1413/2437] SUCCESS: 2022-02-02 - Advisory generated (8,768 chars)
# 🔄 Attempt 1: 13376 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8859 characters
# ✅ [1415/2437] SUCCESS: 2022-02-04 - Advisory generated (8,859 chars)
# 🔄 Attempt 1: 13909 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8718 characters
# ✅ [1416/2437] SUCCESS: 2022-02-05 - Advisory generated (8,718 chars)
# 🔄 Attempt 1: 13296 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8403 characters
# ✅ [1417/2437] SUCCESS: 2022-02-06 - Advisory generated (8,403 chars)
# 🔄 Attempt 1: 13247 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8978 characters
# ✅ [1418/2437] SUCCESS: 2022-02-07 - Advisory generated (8,978 chars)
# 🔄 Attempt 1: 13427 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8845 characters
# ✅ [1419/2437] SUCCESS: 2022-02-08 - Advisory generated (8,845 chars)
# 🔄 Attempt 1: 13770 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8735 characters
# ✅ [1420/2437] SUCCESS: 2022-02-09 - Advisory generated (8,735 chars)
# 🔄 Attempt 1: 13586 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8775 characters
# ✅ [1433/2437] SUCCESS: 2022-02-22 - Advisory generated (8,775 chars)
# 🔄 Attempt 1: 13216 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8378 characters
# ✅ [1426/2437] SUCCESS: 2022-02-15 - Advisory generated (8,378 chars)
# 🔄 Attempt 1: 13420 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8615 characters
# ✅ [1421/2437] SUCCESS: 2022-02-10 - Advisory generated (8,615 chars)
# 🔄 Attempt 1: 13485 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8746 characters
# ✅ [1424/2437] SUCCESS: 2022-02-13 - Advisory generated (8,746 chars)
# 🔄 Attempt 1: 13958 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8972 characters
# ✅ [1427/2437] SUCCESS: 2022-02-16 - Advisory generated (8,972 chars)
# 🔄 Attempt 1: 13746 char prompt, 2000 max tokens, 120s timeout
# 📈 Progress: 1425/2437 (58.5%) | Success: 100.0% | Timeout: 0.0% | Rate: 0.4/sec | ETA: 41.8min
# ✅ Success on attempt 1: Generated 8587 characters
# ✅ [1425/2437] SUCCESS: 2022-02-14 - Advisory generated (8,587 chars)
# 🔄 Attempt 1: 13899 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8462 characters
# ✅ [1423/2437] SUCCESS: 2022-02-12 - Advisory generated (8,462 chars)
# 🔄 Attempt 1: 14082 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8807 characters
# ✅ [1430/2437] SUCCESS: 2022-02-19 - Advisory generated (8,807 chars)
# 🔄 Attempt 1: 14044 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8597 characters
# ✅ [1428/2437] SUCCESS: 2022-02-17 - Advisory generated (8,597 chars)
# 🔄 Attempt 1: 12990 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8826 characters
# ✅ [1432/2437] SUCCESS: 2022-02-21 - Advisory generated (8,826 chars)
# 🔄 Attempt 1: 12836 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8370 characters
# ✅ [1429/2437] SUCCESS: 2022-02-18 - Advisory generated (8,370 chars)
# 🔄 Attempt 1: 13677 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8904 characters
# ✅ [1422/2437] SUCCESS: 2022-02-11 - Advisory generated (8,904 chars)
# 🔄 Attempt 1: 12820 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8745 characters
# ✅ [1434/2437] SUCCESS: 2022-02-23 - Advisory generated (8,745 chars)
# 🔄 Attempt 1: 13095 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8657 characters
# ✅ [1436/2437] SUCCESS: 2022-02-26 - Advisory generated (8,657 chars)
# 🔄 Attempt 1: 13452 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 9045 characters
# ✅ [1431/2437] SUCCESS: 2022-02-20 - Advisory generated (9,045 chars)
# 🔄 Attempt 1: 12778 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8550 characters
# ✅ [1435/2437] SUCCESS: 2022-02-24 - Advisory generated (8,550 chars)
# 🔄 Attempt 1: 13284 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8988 characters
# ✅ [1437/2437] SUCCESS: 2022-02-27 - Advisory generated (8,988 chars)
# 🔄 Attempt 1: 13970 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8580 characters
# ✅ [1438/2437] SUCCESS: 2022-02-28 - Advisory generated (8,580 chars)
# 🔄 Attempt 1: 12697 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8759 characters
# ✅ [1439/2437] SUCCESS: 2022-03-01 - Advisory generated (8,759 chars)
# 🔄 Attempt 1: 14198 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8694 characters
# ✅ [1440/2437] SUCCESS: 2022-03-02 - Advisory generated (8,694 chars)
# 🔄 Attempt 1: 14178 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8657 characters
# ✅ [1441/2437] SUCCESS: 2022-03-03 - Advisory generated (8,657 chars)
# 🔄 Attempt 1: 13104 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8611 characters
# ✅ [1442/2437] SUCCESS: 2022-03-04 - Advisory generated (8,611 chars)
# 🔄 Attempt 1: 12975 char prompt, 2000 max tokens, 120s timeout
# ...
# ✅ Success on attempt 1: Generated 8498 characters
# ✅ [1589/2437] SUCCESS: 2022-08-05 - Advisory generated (8,498 chars)
# 🔄 Attempt 1: 13091 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8674 characters
# ✅ [1592/2437] SUCCESS: 2022-08-08 - Advisory generated (8,674 chars)
# 🔄 Attempt 1: 13507 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8692 characters
# ✅ [1594/2437] SUCCESS: 2022-08-10 - Advisory generated (8,692 chars)
# 🔄 Attempt 1: 13201 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8428 characters
# ✅ [1593/2437] SUCCESS: 2022-08-09 - Advisory generated (8,428 chars)
# 🔄 Attempt 1: 13662 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8289 characters
# ✅ [1595/2437] SUCCESS: 2022-08-11 - Advisory generated (8,289 chars)
# 🔄 Attempt 1: 13979 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 9245 characters
# ✅ [1596/2437] SUCCESS: 2022-08-12 - Advisory generated (9,245 chars)
# 🔄 Attempt 1: 13353 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8697 characters
# ✅ [1597/2437] SUCCESS: 2022-08-13 - Advisory generated (8,697 chars)
# 🔄 Attempt 1: 14046 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8809 characters
# ✅ [1598/2437] SUCCESS: 2022-08-14 - Advisory generated (8,809 chars)
# 🔄 Attempt 1: 13094 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8641 characters
# ✅ [1599/2437] SUCCESS: 2022-08-16 - Advisory generated (8,641 chars)
# 🔄 Attempt 1: 13543 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8531 characters
# ✅ [1600/2437] SUCCESS: 2022-08-17 - Advisory generated (8,531 chars)
# 🔄 Attempt 1: 13569 char prompt, 2000 max tokens, 120s timeout
# 📈 Progress: 1600/2437 (65.7%) | Success: 100.0% | Timeout: 0.0% | Rate: 0.4/sec | ETA: 34.5min
# ✅ Success on attempt 1: Generated 8651 characters
# ✅ [1601/2437] SUCCESS: 2022-08-18 - Advisory generated (8,651 chars)
# 🔄 Attempt 1: 13869 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8388 characters
# ✅ [1602/2437] SUCCESS: 2022-08-19 - Advisory generated (8,388 chars)
# 🔄 Attempt 1: 13567 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8808 characters
# ✅ [1603/2437] SUCCESS: 2022-08-20 - Advisory generated (8,808 chars)
# 🔄 Attempt 1: 13218 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 7983 characters
# ✅ [1604/2437] SUCCESS: 2022-08-21 - Advisory generated (7,983 chars)
# 🔄 Attempt 1: 12830 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8751 characters
# ✅ [1607/2437] SUCCESS: 2022-08-24 - Advisory generated (8,751 chars)
# 🔄 Attempt 1: 13298 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8262 characters
# ✅ [1605/2437] SUCCESS: 2022-08-22 - Advisory generated (8,262 chars)
# 🔄 Attempt 1: 14427 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8276 characters
# ✅ [1606/2437] SUCCESS: 2022-08-23 - Advisory generated (8,276 chars)
# 🔄 Attempt 1: 14142 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8339 characters
# ✅ [1608/2437] SUCCESS: 2022-08-25 - Advisory generated (8,339 chars)
# 🔄 Attempt 1: 13490 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8783 characters
# ✅ [1610/2437] SUCCESS: 2022-08-27 - Advisory generated (8,783 chars)
# 🔄 Attempt 1: 13254 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8649 characters
# ✅ [1609/2437] SUCCESS: 2022-08-26 - Advisory generated (8,649 chars)
# 🔄 Attempt 1: 13566 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8650 characters
# ✅ [1611/2437] SUCCESS: 2022-08-28 - Advisory generated (8,650 chars)
# 🔄 Attempt 1: 13596 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8719 characters
# ✅ [1612/2437] SUCCESS: 2022-08-29 - Advisory generated (8,719 chars)
# 🔄 Attempt 1: 12780 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8221 characters
# ✅ [1613/2437] SUCCESS: 2022-08-30 - Advisory generated (8,221 chars)
# 🔄 Attempt 1: 13329 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8609 characters
# ✅ [1614/2437] SUCCESS: 2022-08-31 - Advisory generated (8,609 chars)
# 🔄 Attempt 1: 13640 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8482 characters
# ✅ [1615/2437] SUCCESS: 2022-09-01 - Advisory generated (8,482 chars)
# 🔄 Attempt 1: 14115 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8499 characters
# ✅ [1616/2437] SUCCESS: 2022-09-02 - Advisory generated (8,499 chars)
# 🔄 Attempt 1: 13135 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8899 characters✅ Success on attempt 1: Generated 8699 characters
# ✅ [1617/2437] SUCCESS: 2022-09-03 - Advisory generated (8,699 chars)
# 🔄 Attempt 1: 13851 char prompt, 2000 max tokens, 120s timeout
#
# ✅ [1618/2437] SUCCESS: 2022-09-04 - Advisory generated (8,899 chars)
# 🔄 Attempt 1: 12915 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8631 characters
# ✅ [1620/2437] SUCCESS: 2022-09-06 - Advisory generated (8,631 chars)
# 🔄 Attempt 1: 13963 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8395 characters
# ✅ [1619/2437] SUCCESS: 2022-09-05 - Advisory generated (8,395 chars)
# 🔄 Attempt 1: 14726 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 9011 characters
# ✅ [1621/2437] SUCCESS: 2022-09-07 - Advisory generated (9,011 chars)
# 🔄 Attempt 1: 14213 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8965 characters
# ✅ [1622/2437] SUCCESS: 2022-09-08 - Advisory generated (8,965 chars)
# 🔄 Attempt 1: 13710 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8570 characters
# ✅ [1623/2437] SUCCESS: 2022-09-09 - Advisory generated (8,570 chars)
# 🔄 Attempt 1: 14186 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8334 characters
# ✅ [1624/2437] SUCCESS: 2022-09-10 - Advisory generated (8,334 chars)
# 🔄 Attempt 1: 13326 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8809 characters
# ✅ [1626/2437] SUCCESS: 2022-09-12 - Advisory generated (8,809 chars)
# 🔄 Attempt 1: 13632 char prompt, 2000 max tokens, 120s timeout
# 📈 Progress: 1625/2437 (66.7%) | Success: 100.0% | Timeout: 0.0% | Rate: 0.4/sec | ETA: 33.6min
# ✅ Success on attempt 1: Generated 8627 characters
# ✅ [1625/2437] SUCCESS: 2022-09-11 - Advisory generated (8,627 chars)
# 🔄 Attempt 1: 13502 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8370 characters
# ✅ [1633/2437] SUCCESS: 2022-09-19 - Advisory generated (8,370 chars)
# 🔄 Attempt 1: 13517 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8657 characters
# ✅ [1627/2437] SUCCESS: 2022-09-13 - Advisory generated (8,657 chars)
# 🔄 Attempt 1: 13536 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8715 characters
# ✅ [1630/2437] SUCCESS: 2022-09-16 - Advisory generated (8,715 chars)
# 🔄 Attempt 1: 14218 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8875 characters
# ✅ [1631/2437] SUCCESS: 2022-09-17 - Advisory generated (8,875 chars)
# 🔄 Attempt 1: 13662 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8474 characters
# ✅ [1634/2437] SUCCESS: 2022-09-20 - Advisory generated (8,474 chars)
# 🔄 Attempt 1: 13602 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8633 characters
# ✅ [1629/2437] SUCCESS: 2022-09-15 - Advisory generated (8,633 chars)
# 🔄 Attempt 1: 13664 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8545 characters
# ✅ [1632/2437] SUCCESS: 2022-09-18 - Advisory generated (8,545 chars)
# 🔄 Attempt 1: 13344 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8914 characters
# ✅ [1628/2437] SUCCESS: 2022-09-14 - Advisory generated (8,914 chars)
# 🔄 Attempt 1: 14886 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8639 characters
# ✅ [1636/2437] SUCCESS: 2022-09-22 - Advisory generated (8,639 chars)
# 🔄 Attempt 1: 14440 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8481 characters
# ✅ [1635/2437] SUCCESS: 2022-09-21 - Advisory generated (8,481 chars)
# 🔄 Attempt 1: 13472 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8709 characters
# ✅ [1637/2437] SUCCESS: 2022-09-23 - Advisory generated (8,709 chars)
# 🔄 Attempt 1: 14097 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8839 characters
# ✅ [1638/2437] SUCCESS: 2022-09-25 - Advisory generated (8,839 chars)
# 🔄 Attempt 1: 13402 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8610 characters
# ✅ [1639/2437] SUCCESS: 2022-09-26 - Advisory generated (8,610 chars)
# 🔄 Attempt 1: 13323 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8857 characters
# ✅ [1640/2437] SUCCESS: 2022-09-27 - Advisory generated (8,857 chars)
# 🔄 Attempt 1: 14554 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8611 characters
# ✅ [1641/2437] SUCCESS: 2022-09-28 - Advisory generated (8,611 chars)
# 🔄 Attempt 1: 13654 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8562 characters
# ✅ [1643/2437] SUCCESS: 2022-09-30 - Advisory generated (8,562 chars)
# 🔄 Attempt 1: 13688 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8481 characters
# ✅ [1642/2437] SUCCESS: 2022-09-29 - Advisory generated (8,481 chars)
# 🔄 Attempt 1: 14342 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8622 characters
# ✅ [1644/2437] SUCCESS: 2022-10-01 - Advisory generated (8,622 chars)
# 🔄 Attempt 1: 14240 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8147 characters
# ✅ [1645/2437] SUCCESS: 2022-10-02 - Advisory generated (8,147 chars)
# 🔄 Attempt 1: 14033 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8444 characters
# ✅ [1646/2437] SUCCESS: 2022-10-03 - Advisory generated (8,444 chars)
# 🔄 Attempt 1: 13627 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8792 characters
# ✅ [1647/2437] SUCCESS: 2022-10-04 - Advisory generated (8,792 chars)
# 🔄 Attempt 1: 13490 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8483 characters
# ✅ [1648/2437] SUCCESS: 2022-10-05 - Advisory generated (8,483 chars)
# 🔄 Attempt 1: 13532 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8707 characters
# ✅ [1649/2437] SUCCESS: 2022-10-06 - Advisory generated (8,707 chars)
# 🔄 Attempt 1: 14421 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8302 characters
# ✅ [1651/2437] SUCCESS: 2022-10-09 - Advisory generated (8,302 chars)
# 🔄 Attempt 1: 13689 char prompt, 2000 max tokens, 120s timeout
# 📈 Progress: 1650/2437 (67.7%) | Success: 100.0% | Timeout: 0.0% | Rate: 0.4/sec | ETA: 32.7min
# ✅ Success on attempt 1: Generated 8398 characters
# ✅ [1650/2437] SUCCESS: 2022-10-07 - Advisory generated (8,398 chars)
# 🔄 Attempt 1: 13181 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8566 characters
# ✅ [1652/2437] SUCCESS: 2022-10-10 - Advisory generated (8,566 chars)
# 🔄 Attempt 1: 14699 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8904 characters
# ✅ [1653/2437] SUCCESS: 2022-10-11 - Advisory generated (8,904 chars)
# 🔄 Attempt 1: 13881 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8431 characters
# ✅ [1654/2437] SUCCESS: 2022-10-12 - Advisory generated (8,431 chars)
# 🔄 Attempt 1: 13326 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8664 characters
# ✅ [1655/2437] SUCCESS: 2022-10-13 - Advisory generated (8,664 chars)
# 🔄 Attempt 1: 13507 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8532 characters
# ✅ [1656/2437] SUCCESS: 2022-10-14 - Advisory generated (8,532 chars)
# 🔄 Attempt 1: 14117 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8776 characters
# ✅ [1658/2437] SUCCESS: 2022-10-16 - Advisory generated (8,776 chars)
# 🔄 Attempt 1: 13629 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8749 characters
# ✅ [1657/2437] SUCCESS: 2022-10-15 - Advisory generated (8,749 chars)
# 🔄 Attempt 1: 13533 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8342 characters
# ✅ [1660/2437] SUCCESS: 2022-10-18 - Advisory generated (8,342 chars)
# 🔄 Attempt 1: 14093 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8957 characters
# ✅ [1659/2437] SUCCESS: 2022-10-17 - Advisory generated (8,957 chars)
# 🔄 Attempt 1: 13169 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8490 characters
# ✅ [1661/2437] SUCCESS: 2022-10-19 - Advisory generated (8,490 chars)
# 🔄 Attempt 1: 13319 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8444 characters
# ✅ [1664/2437] SUCCESS: 2022-10-22 - Advisory generated (8,444 chars)
# 🔄 Attempt 1: 13284 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8627 characters
# ✅ [1662/2437] SUCCESS: 2022-10-20 - Advisory generated (8,627 chars)
# 🔄 Attempt 1: 13247 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8758 characters
# ✅ [1665/2437] SUCCESS: 2022-10-23 - Advisory generated (8,758 chars)
# 🔄 Attempt 1: 14048 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8789 characters
# ✅ [1663/2437] SUCCESS: 2022-10-21 - Advisory generated (8,789 chars)
# 🔄 Attempt 1: 13259 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8348 characters
# ✅ [1666/2437] SUCCESS: 2022-10-24 - Advisory generated (8,348 chars)
# 🔄 Attempt 1: 14465 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8909 characters
# ✅ [1667/2437] SUCCESS: 2022-10-25 - Advisory generated (8,909 chars)
# 🔄 Attempt 1: 13431 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8748 characters
# ✅ [1668/2437] SUCCESS: 2022-10-26 - Advisory generated (8,748 chars)
# 🔄 Attempt 1: 13407 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8549 characters
# ✅ [1669/2437] SUCCESS: 2022-10-27 - Advisory generated (8,549 chars)
# 🔄 Attempt 1: 13602 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8528 characters
# ✅ [1670/2437] SUCCESS: 2022-10-28 - Advisory generated (8,528 chars)
# 🔄 Attempt 1: 13749 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8353 characters
# ✅ [1671/2437] SUCCESS: 2022-10-29 - Advisory generated (8,353 chars)
# 🔄 Attempt 1: 13993 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8685 characters
# ✅ [1675/2437] SUCCESS: 2022-11-02 - Advisory generated (8,685 chars)
# 🔄 Attempt 1: 13833 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8658 characters
# ✅ [1676/2437] SUCCESS: 2022-11-03 - Advisory generated (8,658 chars)
# 🔄 Attempt 1: 10383 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8709 characters
# ✅ [1672/2437] SUCCESS: 2022-10-30 - Advisory generated (8,709 chars)
# 🔄 Attempt 1: 13514 char prompt, 2000 max tokens, 120s timeout
# ✅ Success on attempt 1: Generated 8563 characters
# ✅ [1673/2437] SUCCESS: 2022-10-31 - Advisory generated (8,563 chars)
# 🔄 Attempt 1: 14352 char prompt, 2000 max tokens, 120s timeout
# 📈 Progress: 1675/2437 (68.7%) | Success: 100.0% | Timeout: 0.0% | Rate: 0.4/sec | ETA: 31.3min
# ✅ Success on attempt 1: Generated 8714 characters
# ✅ [1674/2437] SUCCESS: 2022-11-01 - Advisory generated (8,714 chars)
# 🔄 Attempt 1: 13417 char prompt, 2000 max tokens, 120s timeout

# %%
print("📊 Current Processing Status:")
print("="*50)



if 'processing_stats_parallel' in locals():
    with processing_stats_parallel['lock']:
        current_success = processing_stats_parallel['success'] 
        current_timeout = processing_stats_parallel['timeout']
        current_error = processing_stats_parallel['error']
        current_total = processing_stats_parallel['total']
    
    if current_total > 0:
        success_rate = (current_success / current_total * 100)
        timeout_rate = (current_timeout / current_total * 100) 
        error_rate = (current_error / current_total * 100)
        
        print(f"📈 Processed: {current_total:,} / {len(df_daily_investment):,} samples")
        print(f"✅ Success: {current_success:,} ({success_rate:.1f}%)")
        print(f"⏰ Timeout: {current_timeout:,} ({timeout_rate:.1f}%)")
        print(f" Error: {current_error:,} ({error_rate:.1f}%)")
        print(f"📋 Advisory Samples: {len(advisory_samples_parallel):,}")
        
        if current_total == len(df_daily_investment):
            print("\n🎉 PROCESSING COMPLETE!")
        else:
            progress_pct = (current_total / len(df_daily_investment)) * 100
            print(f"⚡ Progress: {progress_pct:.1f}% complete")
    else:
        print("⏳ Processing starting...")
else:
    print("⚠️  Parallel processing not started yet")


if 'advisory_samples_parallel' in locals() and len(advisory_samples_parallel) > 0:
    print(f"\n📝 Latest Advisory Sample ({advisory_samples_parallel[-1]['date'][:10]}):")
    print("-" * 50)
    latest_advisory = advisory_samples_parallel[-1]['advisory']
    print(latest_advisory[:300] + "..." if len(latest_advisory) > 300 else latest_advisory)
# Out:
# 📊 Current Processing Status:
# ==================================================
# 📈 Processed: 2,437 / 2,437 samples
# ✅ Success: 0 (0.0%)
# ⏰ Timeout: 0 (0.0%)
# ❌ Error: 2,437 (100.0%)
# 📋 Advisory Samples: 0
#
# 🎉 PROCESSING COMPLETE!
